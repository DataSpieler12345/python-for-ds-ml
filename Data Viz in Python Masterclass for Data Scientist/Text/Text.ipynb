# %%
import matplotlib.pyplot as plt

# %%
plt.title('axes title')
plt.xlabel('xlabel')
plt.ylabel('ylabel')

plt.text(3, 8, 'boxed italics text in data coords', style='italic', bbox={'facecolor': 'red'})
plt.text(2, 6, r'an equation: $E = mc^2$', fontsize=15)
plt.text(4, 0.05, 'colored text in axes coords', verticalalignment='bottom', color='green', fontsize=15)
# Out:
# Text(4, 0.05, 'colored text in axes coords')

# %%
plt.title('axes title')
plt.xlabel('xlabel')
plt.ylabel('ylabel')

plt.text(3, 8, 'boxed italics text in data coords', style='italic', bbox={'facecolor': 'red'})
plt.text(2, 6, r'an equation: $E = mc^2$', fontsize=15)
plt.text(4, 0.05, 'colored text in axes coords', verticalalignment='bottom', color='green', fontsize=15)
plt.plot([2], [1], 'o')

# %%
plt.title('axes title')
plt.xlabel('xlabel')
plt.ylabel('ylabel')

plt.text(3, 8, 'boxed italics text in data coords', style='italic', bbox={'facecolor': 'red'})
plt.text(2, 6, r'an equation: $E = mc^2$', fontsize=15)
plt.text(4, 0.05, 'colored text in axes coords', verticalalignment='bottom', color='green', fontsize=15)
plt.plot([2], [1], 'o')

plt.axis([0,10,0,10])
# Out:
# (0.0, 10.0, 0.0, 10.0)

# %%
plt.title('axes title')
plt.xlabel('xlabel')
plt.ylabel('ylabel')

plt.text(3, 8, 'boxed italics text in data coords', style='italic', bbox={'facecolor': 'red'})
plt.text(2, 6, r'an equation: $E = mc^2$', fontsize=15)
plt.text(4, 0.05, 'colored text in axes coords', verticalalignment='bottom', color='green', fontsize=15)
plt.plot([2], [1], 'o')
plt.annotate('annotate', xy=(2,1), xytext=(3,4), arrowprops=dict(facecolor='black', shrink=0.05))

plt.axis([0,10,0,10])
# Out:
# (0.0, 10.0, 0.0, 10.0)
