# %% [markdown]
# ## What is matplotlib?
# #### * It is an open source drawing library which supports rich drawing types
# #### * It is used to draw 2D and 3D graphics
# #### * You can understand your data easily by visualizing it with the help of matplotlib!
# #### * You can generate plots, histograms, bar charts and many other charts with just a few lines of code

# %%
from matplotlib import pylab #importing corresponding packages
print(pylab.__version__)
# Out:
# 1.21.5

# %%
#### Use Numpy to generate random data

"""Use Numpy to generate random data
"""
import numpy as np
x = np.linspace(0, 10, 25)
y = x * x + 2
print(x)
print(y)
# Out:
# [ 0.          0.41666667  0.83333333  1.25        1.66666667  2.08333333
#   2.5         2.91666667  3.33333333  3.75        4.16666667  4.58333333
#   5.          5.41666667  5.83333333  6.25        6.66666667  7.08333333
#   7.5         7.91666667  8.33333333  8.75        9.16666667  9.58333333
#  10.        ]
# [  2.           2.17361111   2.69444444   3.5625       4.77777778
#    6.34027778   8.25        10.50694444  13.11111111  16.0625
#   19.36111111  23.00694444  27.          31.34027778  36.02777778
#   41.0625      46.44444444  52.17361111  58.25        64.67361111
#   71.44444444  78.5625      86.02777778  93.84027778 102.        ]

# %%
print(np.array([x,y]).reshape(25,2)) #another way
# Out:
# [[  0.           0.41666667]
#  [  0.83333333   1.25      ]
#  [  1.66666667   2.08333333]
#  [  2.5          2.91666667]
#  [  3.33333333   3.75      ]
#  [  4.16666667   4.58333333]
#  [  5.           5.41666667]
#  [  5.83333333   6.25      ]
#  [  6.66666667   7.08333333]
#  [  7.5          7.91666667]
#  [  8.33333333   8.75      ]
#  [  9.16666667   9.58333333]
#  [ 10.           2.        ]
#  [  2.17361111   2.69444444]
#  [  3.5625       4.77777778]
#  [  6.34027778   8.25      ]
#  [ 10.50694444  13.11111111]
#  [ 16.0625      19.36111111]
#  [ 23.00694444  27.        ]
#  [ 31.34027778  36.02777778]
#  [ 41.0625      46.44444444]
#  [ 52.17361111  58.25      ]
#  [ 64.67361111  71.44444444]
#  [ 78.5625      86.02777778]
#  [ 93.84027778 102.        ]]

# %%
print(np.array([x,y]).reshape(25,2).reshape(2,25)) # another way
# Out:
# [[  0.           0.41666667   0.83333333   1.25         1.66666667
#     2.08333333   2.5          2.91666667   3.33333333   3.75
#     4.16666667   4.58333333   5.           5.41666667   5.83333333
#     6.25         6.66666667   7.08333333   7.5          7.91666667
#     8.33333333   8.75         9.16666667   9.58333333  10.        ]
#  [  2.           2.17361111   2.69444444   3.5625       4.77777778
#     6.34027778   8.25        10.50694444  13.11111111  16.0625
#    19.36111111  23.00694444  27.          31.34027778  36.02777778
#    41.0625      46.44444444  52.17361111  58.25        64.67361111
#    71.44444444  78.5625      86.02777778  93.84027778 102.        ]]

# %%
"""It only takes 1 comand to draw
"""
pylab.plot(x,y, 'r') #'r stands for red'

# %%
"""Drawing a subgraph
"""
pylab.subplot(1,2,1)# The contents of the brackets represent (rows, columns, indexes)
pylab.plot(x,y, 'r--')# The third parameter here determines color and line style
pylab.subplot(1,2, 2)
pylab.plot(y,x, 'g*-')

# %%
"""Drawing a subgraph
"""
pylab.subplot(1,2,1)# The contents of the brackets represent (rows, columns, indexes)
pylab.plot(x,y, 'r--')# The third parameter here determines color and line style
pylab.subplot(1,2, 1)
pylab.plot(y,x, 'g*-')

# %%
"""Drawing a subgraph
"""
pylab.subplot(1,1,1)# The contents of the brackets represent (rows, columns, indexes)
pylab.plot(x,y, 'r--')# The third parameter here determines color and line style
pylab.subplot(1,2, 2)
pylab.plot(y,x, 'g*-')

# %%
"""Drawing a subgraph
"""
pylab.subplot(1,2,1)# The contents of the brackets represent (rows, columns, indexes)
pylab.plot(x,y, 'r--')# The third parameter here determines color and line style
pylab.subplot(2,2, 2)
pylab.plot(y,x, 'g*-')

# %%
"""Drawing a subgraph
"""
pylab.subplot(1,2,1)# The contents of the brackets represent (rows, columns, indexes)
pylab.plot(x,y, 'r--')# The third parameter here determines color and line style
pylab.subplot(2,2, 3)
pylab.plot(y,x, 'g*-')

# %%
"""Drawing a subgraph
"""
pylab.subplot(2,2,1)# The contents of the brackets represent (rows, columns, indexes)
pylab.plot(x,y, 'r--')# The third parameter here determines color and line style
pylab.subplot(2,3, 3)
pylab.plot(y,x, 'g*-')

# %%
"""Drawing a subgraph
"""
pylab.subplot(1,2,1)# The contents of the brackets represent (rows, columns, indexes)
pylab.plot(x,y, 'r--')# The third parameter here determines color and line style
pylab.subplot(1,2, 2)
pylab.plot(y,x, 'g*-')

# %%
#(1,2,1) and (1,2,2) are significant if we want tiled subplots, without which both the graphs will in the same 

#for example
pylab.subplot(1,2,1)# The contents of the brackets represent (rows, columns, indexes)
pylab.plot(x,y, 'r--')# The third parameter here determines color and line style
pylab.subplot(1,2, 1)
pylab.plot(y,x, 'g*-')

# %% [markdown]
# #### Operator Description
#
# fig.add_axes()= Initializes subplot a = fig.add_subplot(222)
#
# fig, b = plt.subplots(nrows=3, nclos=2)=Adds subplot
#
# ax = plt.subplots(2,2)= Creates subplot

# %%
# importing pyplot
from matplotlib import pyplot as plt

# %%
fig = plt.figure()

axis = fig.add_axes([0.5, 0.1, 0.8, 0.8]) #Control the left, right, width, height of the canvas (from 0 to 1)

axis.plot(x,y, 'r')

# %%
# and again we can draw subgraphs
fig, axes = plt.subplots(nrows = 1, ncols=2) #Submap is of 1 row, 2 columns
for ax in axes:
    ax.plot(x,y, 'r')

# %%
# and again we can draw subgraphs
fig, axes = plt.subplots(nrows = 2, ncols=1) #Submap is of 1 row, 2 columns
for ax in axes:
    ax.plot(x,y, 'r')

# %%
# and again we can draw subgraphs
fig, axes = plt.subplots(nrows = 1, ncols=2) #Submap is of 1 row, 2 columns
for ax in axes:
    ax.plot(x,y, 'r')

# %%
# We can also draw a picture, or graph, inside another graph
fig = plt.figure()

#Control the left, right,bottom, width, height of the canvas (from 0 to 1)

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # big axes
axes2 = fig.add_axes([0.2, 0.5, 0.4, 0.3]) # small canvas

axes1.plot(x,y, 'r')
axes2.plot(y, x, 'g')

# %%
# We can also draw a picture, or graph, inside another graph
fig = plt.figure()

#Control the left, right, bottom, width, height of the canvas (from 0 to 1)

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # big axes
axes2 = fig.add_axes([0.1, 0.5, 0.4, 0.3]) # small canvas

axes1.plot(x,y, 'r')
axes2.plot(y, x, 'g')

# %%
# We can also draw a picture, or graph, inside another graph
fig = plt.figure()

#Control the left, right, bottom, width, height of the canvas (from 0 to 1)

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # big axes
axes2 = fig.add_axes([0.4, 0.5, 0.4, 0.3]) # small canvas

axes1.plot(x,y, 'r')
axes2.plot(y, x, 'g')

# %%
# We can also draw a picture, or graph, inside another graph
fig = plt.figure()

#Control the left, right, bottom, width, height of the canvas (from 0 to 1)

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # big axes
axes2 = fig.add_axes([0.2, 0.1, 0.4, 0.3]) # small canvas

axes1.plot(x,y, 'r')
axes2.plot(y, x, 'g')

# %%
# We can also draw a picture, or graph, inside another graph
fig = plt.figure()

#Control the left, right, width, height of the canvas (from 0 to 1)

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # big axes
axes2 = fig.add_axes([0.2, 0.5, 0.3, 0.3]) # small canvas

axes1.plot(x,y, 'r')
axes2.plot(y, x, 'g')

# %%
# We can also draw a picture, or graph, inside another graph
fig = plt.figure()

#Control the left, right, width, height of the canvas (from 0 to 1)

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # big axes
axes2 = fig.add_axes([0.2, 0.5, 0.3, 0.2]) # small canvas

axes1.plot(x,y, 'r')
axes2.plot(y, x, 'g')

# %%
# We can also draw a picture, or graph, inside another graph
fig = plt.figure()

#Control the left, right, width, height of the canvas (from 0 to 1)

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # big axes
axes2 = fig.add_axes([0.2, 0.7, 0.2, 0.2]) # small canvas

axes1.plot(x,y, 'r')
axes2.plot(y, x, 'g')

# %%
# We can also draw a picture, or graph, inside another graph
fig = plt.figure()

#Control the left, right, width, height of the canvas (from 0 to 1)

axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8]) # big axes
axes2 = fig.add_axes([0.2, 0.6, 0.2, 0.2]) # small canvas

axes1.plot(x,y, 'r')
axes2.plot(y, x, 'g')

# %% [markdown]
# ### New Graphic Object

# %%
fig = plt.figure(figsize=(16,9), dpi=300) #New graphic object

fig.add_subplot()

plt.plot(x, y, 'r')

# %%
fig = plt.figure(figsize=(16,9), dpi=600) #New graphic object

fig.add_subplot()

plt.plot(x, y, 'r')

# %%
fig = plt.figure(figsize=(16,9), dpi=100) #New graphic object

fig.add_subplot()

plt.plot(x, y, 'r')

# %%
fig = plt.figure(figsize=(16,9), dpi=50) #New graphic object

fig.add_subplot()

plt.plot(x, y, 'r')

# %%
fig, axes = plt.subplots(figsize=(16,9), dpi=50)
axes.plot(x, y, 'r')

# %%
fig, axes = plt.subplots()
axes.plot(x, y, 'r')

# %%
fig, axes = plt.subplots()
axes.set_xlabel("x-label")
axes.set_ylabel("y-label")

axes.set_title("title of graph")

axes.plot(x, y, 'r')

# %%
ax.legend(["label1", "label2"])

fig, axes = plt.subplots()
axes.set_xlabel("x-label")
axes.set_ylabel("y-label")

axes.set_title("title of graph")

axes.plot(x, x**2)
axes.plot(x, x**3)

# %%
ax.legend(["label1", "label2"])

fig, axes = plt.subplots()
axes.set_xlabel("x-label")
axes.set_ylabel("y-label")

axes.set_title("title of graph")

axes.plot(x, x**2)
axes.plot(x, x**3)

#adding legend
axes.legend(["y = x**2", "y = x**3"], loc=2) #loc define de position of the legend

# %%
ax.legend(["label1", "label2"])

fig, axes = plt.subplots()
axes.set_xlabel("x-label")
axes.set_ylabel("y-label")

axes.set_title("title of graph")

axes.plot(x, x**2)
axes.plot(x, x**3)

#adding legend
axes.legend(["y = x**2", "y = x**3"], loc=1) #loc define de position of the legend

# %%
ax.legend(["label1", "label2"])

fig, axes = plt.subplots(dpi=200) #dpi define de size
axes.set_xlabel("x-label")
axes.set_ylabel("y-label")

axes.set_title("title of graph")

axes.plot(x, x**2)
axes.plot(x, x**3)

#adding legend
axes.legend(["y = x**2", "y = x**3"], loc=0) #loc define de position of the legend

# %%
ax.legend(["label1", "label2"])

fig, axes = plt.subplots(dpi=150)
axes.set_xlabel("x-label")
axes.set_ylabel("y-label")

axes.set_title("title of graph")

axes.plot(x, x**2)
axes.plot(x, x**3)

#adding legend
axes.legend(["y = x**2", "y = x**3"], loc=6) #loc define de position of the legend

# %%
ax.legend(["label1", "label2"])

fig, axes = plt.subplots()
axes.set_xlabel("x-label")
axes.set_ylabel("y-label")

axes.set_title("title of graph")

axes.plot(x, x**2)
axes.plot(x, x**3)

#adding legend
axes.legend(["y = x**2", "y = x**3"], loc=1) #loc define de position of the legend

# %% [markdown]
# #### In Maplotlib, you can set other properties such as line color, transparency, and more.

# %%
fig, axes = plt.subplots(dpi=150)
axes.plot(x, x+1)
axes.plot(x, x+2)
axes.plot(x, x+3)

# %%
fig, axes = plt.subplots(dpi=150)
axes.plot(x, x+1, color='red') #colors
axes.plot(x, x+2, color="#1155dd") #colors
axes.plot(x, x+3, color="#15cc55") #colors

# %%
fig, axes = plt.subplots(dpi=150)
axes.plot(x, x+1, color='red') #colors
axes.plot(x, x+2, color="blue") #colors
axes.plot(x, x+3, color="green") #colors

# %%
fig, axes = plt.subplots(dpi=150)
axes.plot(x, x+1, color='red', alpha=.5) #colors, red like pink
axes.plot(x, x+2, color="blue") #colors
axes.plot(x, x+3, color="green") #colors

# %%
fig, axes = plt.subplots(dpi=150)
axes.plot(x, x**2, color='red', alpha=.5) #colors, red like pink, behind de others colors
axes.plot(x, x+2, color="blue") #colors
axes.plot(x, x+3, color="green") #colors

# %%
fig, axes = plt.subplots(dpi=150)
axes.plot(x, x**2, color='red', alpha=.5) #colors, red like pink behind the blue
axes.plot(x, x+2, color='blue', alpha=.5) #colors
axes.plot(x, x+3, color='green') #colors

# %%
fig, axes = plt.subplots(dpi=150)
axes.plot(x, x**2, color='red', alpha=.5) #colors, red like pink behind the other colors
axes.plot(x, x+2, color='blue', alpha=.5) #colors
axes.plot(x, x+3, color='green', alpha=.5) #colors

# %%
fig, axes = plt.subplots(dpi=150)
axes.plot(x, x**2, color='red', alpha=.8) #colors, red like pink behind the other colors
axes.plot(x, x+2, color='blue', alpha=.8) #colors
axes.plot(x, x+3, color='green', alpha=.8) #colors

# %%
fig, axes = plt.subplots(dpi=150)
axes.plot(x, x**2, color='red', alpha=.3) #colors, red like pink behind the other colors
axes.plot(x, x+2, color='blue', alpha=.3) #colors
axes.plot(x, x+3, color='green', alpha=.3) #colors

# %% [markdown]
# ### Series Presentation

# %%
fix, ax =plt.subplots(dpi=100)

#line width, custom....
ax.plot(x, x+1, color='blue', linewidth=0.25)
ax.plot(x, x+2, color='blue', linewidth=1)
ax.plot(x, x+3, color='blue', linewidth=1.50)
ax.plot(x, x+4, color='blue', linewidth=2)

# %%
fix, ax =plt.subplots(dpi=100)

#line style, custom....
ax.plot(x, x+1, color='blue', lw=2, linestyle='-')
ax.plot(x, x+2, color='blue', lw=2, linestyle='-.')
ax.plot(x, x+3, color='blue', lw=2, linestyle=':')

# %%
fix, ax =plt.subplots(dpi=100)

#line style, custom....
ax.plot(x, x+1, color='blue', lw=2, linestyle='-')
ax.plot(x, x+2, color='blue', lw=2, linestyle='-.')
ax.plot(x, x+3, color='blue', lw=2, linestyle=':')

line, = ax.plot(x, x+4, color='black', lw=1.50)
line.set_dashes([5, 10, 15, 10])

# %%
fix, ax =plt.subplots(dpi=100)

#line style, custom....
ax.plot(x, x+1, color='blue', lw=2, linestyle='-')
ax.plot(x, x+2, color='blue', lw=2, linestyle='-.')
ax.plot(x, x+3, color='blue', lw=2, linestyle=':')

line, = ax.plot(x, x+4, color='black', lw=1.50)
line.set_dashes([5, 10, 15, 10])

line, = ax.plot(x, x+5, color='black', lw=1.50)
line.set_dashes([5, 10, 15, 3]) #

line, = ax.plot(x, x+6, color='black', lw=1.50)
line.set_dashes([5, 10, 4, 10]) #playing with the numbers

# %%
fix, ax =plt.subplots(dpi=100)

#line style, custom....
ax.plot(x, x+1, color='blue', lw=2, linestyle='-')
ax.plot(x, x+2, color='blue', lw=2, linestyle='-.')
ax.plot(x, x+3, color='blue', lw=2, linestyle=':')

line, = ax.plot(x, x+4, color='black', lw=1.50)
line.set_dashes([5, 10, 15, 10])

line, = ax.plot(x, x+5, color='black', lw=1.50)
line.set_dashes([5, 10, 15, 3]) #playing with the numbers

line, = ax.plot(x, x+6, color='black', lw=1.50)
line.set_dashes([5, 10, 4, 30]) #playing with the numbers

# %%
fix, ax =plt.subplots(dpi=100)

#line style, custom....
ax.plot(x, x+1, color='blue', lw=2, linestyle='-')
ax.plot(x, x+2, color='blue', lw=2, linestyle='-.')
ax.plot(x, x+3, color='blue', lw=2, linestyle=':')

line, = ax.plot(x, x+4, color='black', lw=1.50)
line.set_dashes([5, 10, 15, 10])

line, = ax.plot(x, x+5, color='black', lw=1.50)
line.set_dashes([5, 10, 15, 3]) #playing with the numbers

line, = ax.plot(x, x+6, color='black', lw=1.50)
line.set_dashes([5, 10, 30, 30]) #playing with the numbers

# %%
fix, ax =plt.subplots(dpi=100)

#line width, custom....
ax.plot(x, x+1, color='blue', marker='o')
ax.plot(x, x+2, color='blue', marker='+')
ax.plot(x, x+3, color='blue', marker='s')
ax.plot(x, x+4, color='blue', marker='1')

ax.plot(x, x+5, color='blue', marker='o', markersize=5)
ax.plot(x, x+6, color='blue', marker='s', markerfacecolor='red')
ax.plot(x, x+7, color='blue', marker='o', markersize=15, markerfacecolor='green')

# %%
fix, ax =plt.subplots(dpi=100)

#line width, custom....
ax.plot(x, x+1, color='blue', marker='o')
ax.plot(x, x+2, color='blue', marker='+')
ax.plot(x, x+3, color='blue', marker='s')
ax.plot(x, x+4, color='blue', marker='1')

ax.plot(x, x+5, color='blue', marker='o', markersize=5)
ax.plot(x, x+6, color='blue', marker='s', markerfacecolor='red')
ax.plot(x, x+7, color='blue', marker='o', markersize=8, markerfacecolor='green')

# %% [markdown]
# ### Limited Data

# %%
""" Set the canvas grid and axis range
"""
fig, Axes = plt.subplots(1, 2, figsize=(10,5))

Axes[0].plot(x, x**2, x, x**3, lw=2)
Axes[0].grid(True)

# %%
#Axes_1 taking
""" Set the canvas grid and axis range
"""
fig, Axes = plt.subplots(1, 2, figsize=(10,5))

Axes[0].plot(x, x**2, x, x**3, lw=2)
Axes[0].grid(True)

Axes[1].plot(x, x**2, x, x**3, lw=2)
Axes[1].set_ylim([0,60])
Axes[1].set_xlim([2,5])
Axes[1].grid(True) #grid on

# %% [markdown]
# ### Other 2D Graphics

# %%
n = np.array([0,1,2,3,4,5])

fix, axes = plt.subplots(1, 4, figsize=(16,5))

# %%
n = np.array([0,1,2,3,4,5])

fix, axes = plt.subplots(1, 4, figsize=(16,5))
axes[0].set_title('scatter plot')
axes[0].scatter(x, x + 0.25*np.random.randn(len(x)))

# %%
n = np.array([0,1,2,3,4,5])

fix, axes = plt.subplots(1, 4, figsize=(16,5))
axes[0].set_title('scatter plot')
axes[0].scatter(x, x + 0.25*np.random.randn(len(x)))

axes[1].set_title('step')
axes[1].step(n, n**2, lw=2)

# %%
n = np.array([0,1,2,3,4,5])

fix, axes = plt.subplots(1, 4, figsize=(16,5))
axes[0].set_title('scatter plot')
axes[0].scatter(x, x + 0.25*np.random.randn(len(x)))

axes[1].set_title('step')
axes[1].step(n, n**2, lw=2)

axes[2].set_title('bar')
axes[2].bar(n, n**2, align='center', alpha=0.5)
# Out:
# <BarContainer object of 6 artists>

# %%
n = np.array([0,1,2,3,4,5])

fix, axes = plt.subplots(1, 4, figsize=(16,5))
axes[0].set_title('scatter plot')
axes[0].scatter(x, x + 0.25*np.random.randn(len(x)))

axes[1].set_title('step')
axes[1].step(n, n**2, lw=2)

axes[2].set_title('bar')
axes[2].bar(n, n**2, align='center', alpha=0.5)

axes[3].set_title('fill_between')
axes[3].fill_between(x, x**2, x**3, color="green", alpha=0.5)

# %% [markdown]
# ### Drawing a radar chart

# %%
"""Draw a readar chart
"""

fig = plt.figure(figsize=(6,6))
ax = fig.add_axes([0.0, 0.0, .6, .6], polar=True)

# %%
"""Draw a readar chart
"""

fig = plt.figure(figsize=(6,6))
ax = fig.add_axes([0.0, 0.0, 1, 1], polar=True)

# %%
"""Draw a readar chart
"""

fig = plt.figure(figsize=(6,6))
ax = fig.add_axes([0.0, 0.0, 1, 1], polar=True)
t = np.linspace(0, 2 * np.pi, 100)

# %%
"""Draw a readar chart
"""

fig = plt.figure(figsize=(6,6))
ax = fig.add_axes([0.0, 0.0, 1, 1], polar=True)
t = np.linspace(0, 2 * np.pi, 100)
ax.plot(t,t, color='blue', lw=3)

# %%
"""Draw a readar chart
"""

fig = plt.figure(figsize=(6,6))
ax = fig.add_axes([0.0, 0.0, 1, 1], polar=True)
t = np.linspace(0, 2 * np.pi, 100)
ax.plot(t,t * 5, color='blue', lw=3)

# %% [markdown]
# ### Drawing a histogram

# %%
"""Draw a histogram
"""

n = np.random.randn(100000)
fig, axes = plt.subplots(1, 2, figsize=(12,4))
axes[0].set_title("Default histogram")
axes[0].hist(n)
# Out:
# (array([2.5000e+01, 3.6800e+02, 3.2390e+03, 1.3987e+04, 2.9954e+04,
#         3.1544e+04, 1.6141e+04, 4.2170e+03, 4.8800e+02, 3.7000e+01]),
#  array([-4.40049921, -3.53230886, -2.66411852, -1.79592818, -0.92773784,
#         -0.0595475 ,  0.80864285,  1.67683319,  2.54502353,  3.41321387,
#          4.28140422]),
#  <BarContainer object of 10 artists>)

# %%
"""Draw a histogram
"""

n = np.random.randn(100000)
fig, axes = plt.subplots(1, 2, figsize=(12,4))
axes[0].set_title("Default histogram")
axes[0].hist(n)

axes[1].set_title("Cumulative detailed histogram")
axes[1].hist(n, cumulative=True, bins=10)
# Out:
# (array([5.3000e+01, 7.8900e+02, 5.4650e+03, 2.1656e+04, 5.1315e+04,
#         8.0176e+04, 9.5177e+04, 9.9286e+04, 9.9944e+04, 1.0000e+05]),
#  array([-4.03929369, -3.22376545, -2.40823721, -1.59270897, -0.77718072,
#          0.03834752,  0.85387576,  1.669404  ,  2.48493224,  3.30046049,
#          4.11598873]),
#  <BarContainer object of 10 artists>)

# %%
"""Draw a histogram
"""

n = np.random.randn(100000)
fig, axes = plt.subplots(1, 2, figsize=(12,4))
axes[0].set_title("Default histogram")
axes[0].hist(n)

axes[1].set_title("Cumulative detailed histogram")
axes[1].hist(n, cumulative=True, bins=5)
# Out:
# (array([   363.,  17982.,  80406.,  99573., 100000.]),
#  array([-4.4417557 , -2.67771725, -0.91367881,  0.85035964,  2.61439808,
#          4.37843653]),
#  <BarContainer object of 5 artists>)

# %%
"""Draw a histogram
"""

n = np.random.randn(100000)
fig, axes = plt.subplots(1, 2, figsize=(12,4))
axes[0].set_title("Default histogram")
axes[0].hist(n)

axes[1].set_title("Cumulative detailed histogram")
axes[1].hist(n, bins=8)
# Out:
# (array([1.2700e+02, 2.4230e+03, 1.6494e+04, 3.8768e+04, 3.1795e+04,
#         9.4240e+03, 9.3700e+02, 3.2000e+01]),
#  array([-4.08149703, -3.01262398, -1.94375093, -0.87487787,  0.19399518,
#          1.26286823,  2.33174128,  3.40061433,  4.46948738]),
#  <BarContainer object of 8 artists>)

# %%
"""Draw a histogram
"""

n = np.random.randn(100000)
fig, axes = plt.subplots(1, 2, figsize=(12,4))
axes[0].set_title("Default histogram")
axes[0].hist(n)

axes[1].set_title("Cumulative detailed histogram")
axes[1].hist(n, cumulative=True, bins=8)
# Out:
# (array([4.1000e+01, 1.2020e+03, 1.2600e+04, 4.8777e+04, 8.5838e+04,
#         9.8570e+04, 9.9948e+04, 1.0000e+05]),
#  array([-4.47821815, -3.36774988, -2.25728162, -1.14681335, -0.03634509,
#          1.07412318,  2.18459144,  3.29505971,  4.40552797]),
#  <BarContainer object of 8 artists>)

# %% [markdown]
# ### Drawing a contour image

# %%
import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt

delta = 0.025
x = np.arange(-3.0 , 3.0, delta)
y = np.arange(-2.0 , 2.0, delta)
X, Y = np.meshgrid(x, y)
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(X - 1)**2 - (Y - 1)**2)
Z = (Z1 - Z2) * 2

print(X)
print(Y)
# Out:
# [[-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  ...
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]]
# [[-2.    -2.    -2.    ... -2.    -2.    -2.   ]
#  [-1.975 -1.975 -1.975 ... -1.975 -1.975 -1.975]
#  [-1.95  -1.95  -1.95  ... -1.95  -1.95  -1.95 ]
#  ...
#  [ 1.925  1.925  1.925 ...  1.925  1.925  1.925]
#  [ 1.95   1.95   1.95  ...  1.95   1.95   1.95 ]
#  [ 1.975  1.975  1.975 ...  1.975  1.975  1.975]]

# %%
fig, ax = plt.subplots()
CS = ax.contour(X, Y, Z)
ax.clabel(CS, inline=1, fontsize=10)
ax.set_title('contour map')
# Out:
# Text(0.5, 1.0, 'contour map')

# %% [markdown]
# ### Drawing 3D surface image

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

fig = plt.figure(figsize=(14,6))

# Specify the 3D graphics to draw, with projection='3D'
ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

fig = plt.figure(figsize=(14,6))

# Specify the 3D graphics to draw, with projection='3D'
ax = fig.add_subplot(2, 3, 1, projection='3d') #numbers
ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

fig = plt.figure(figsize=(14,6))

# Specify the 3D graphics to draw, with projection='3D'
ax = fig.add_subplot(2, 7, 1, projection='3d') #numbers
ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

fig = plt.figure(figsize=(14,12)) #changing the size numbers

# Specify the 3D graphics to draw, with projection='3D'
ax = fig.add_subplot(1, 1, 1, projection='3d') #numbers
ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

# %% [markdown]
# ### Drawing a heatmap....color map

# %% [markdown]
# ##### practice example
# ##### Write a Python programming to create a pie chart of the popularity of programming languages

# %%
import matplotlib.pyplot as plt

#Data to plot
languages = 'Python', 'Java', 'PHP', 'JavaScript', 'C#', 'C++'
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]
colors = ["#1f77b4", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd", "#8c564b"]

# %%
# explode 1st slice
explode = (0.1, 0, 0, 0,0,0)
plt.pie(popularity)
# Out:
# ([<matplotlib.patches.Wedge at 0x11ab461cdf0>,
# ...
#  [Text(0.6106212455488447, 0.914954476727874, ''),
#   Text(-1.0139237282141302, 0.42656614184011216, ''),
#   Text(-0.7897694469856671, -0.7656789278855424, ''),
#   Text(-0.06323929665114071, -1.0981806733680344, ''),
#   Text(0.654413852726294, -0.8841620379545417, ''),
#   Text(1.0520142924916651, -0.3213501647630839, '')])

# %%
explode = (0.1, 0, 0, 0,0,0)
plt.pie(popularity, explode=explode, labels=languages, colors=colors,
       autopct='%1.1f%%', shadow=True, startangle=140)
# Out:
# ([<matplotlib.patches.Wedge at 0x11ab464fdf0>,
# ...
#  [Text(-1.1518739051683529, -0.33643202373170245, 'Python'),
#   Text(0.5025192070582963, -0.978506232242545, 'Java'),
#   Text(1.0971674240514186, 0.07889007288863878, 'PHP'),
#   Text(0.754341041824552, 0.8006057660415953, 'JavaScript'),
#   Text(0.06701830757132049, 1.0979565321315212, 'C#'),
#   Text(-0.5993297985645449, 0.9223902604389219, 'C++')],
#  [Text(-0.6719264446815391, -0.19625201384349306, '31.3%'),
#   Text(0.2741013856681616, -0.5337306721322972, '24.8%'),
#   Text(0.5984549585735011, 0.043030948848348426, '12.4%'),
#   Text(0.41145875008611926, 0.4366940542045065, '11.3%'),
#   Text(0.036555440493447534, 0.5988853811626479, '10.8%'),
#   Text(-0.3269071628533881, 0.5031219602394119, '9.4%')])

# %%
explode = (0.1, 0, 0, 0,0,0)
plt.pie(popularity, explode=explode, labels=languages, colors=colors,
       autopct='%1.1f%%', shadow=True, startangle=90)
# Out:
# ([<matplotlib.patches.Wedge at 0x11ab46b1b80>,
# ...
#  [Text(-0.9981321564304079, 0.6661322678714671, 'Python'),
#   Text(-0.42656614184011216, -1.0139237282141302, 'Java'),
#   Text(0.7656789278855427, -0.7897694469856669, 'PHP'),
#   Text(1.0981806733680344, -0.06323929665114078, 'JavaScript'),
#   Text(0.8841620379545417, 0.6544138527262939, 'C#'),
#   Text(0.321350164763084, 1.0520142924916651, 'C++')],
#  [Text(-0.5822437579177379, 0.38857715625835576, '31.3%'),
#   Text(-0.23267244100369752, -0.5530493062986164, '24.8%'),
#   Text(0.4176430515739324, -0.4307833347194546, '12.4%'),
#   Text(0.5990076400189277, -0.034494161809713146, '11.3%'),
#   Text(0.48227020252065905, 0.3569530105779785, '10.8%'),
#   Text(0.17528190805259122, 0.5738259777227264, '9.4%')])

# %%
explode = (0.1, 0, 0, 0,0,0)
plt.pie(popularity, explode=explode, labels=languages, colors=colors,
       autopct='%1.1f%%', shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x11ab4719730>,
# ...
#  [Text(0.666132267871467, 0.998132156430408, 'Python'),
#   Text(-1.0139237282141302, 0.42656614184011216, 'Java'),
#   Text(-0.7897694469856671, -0.7656789278855424, 'PHP'),
#   Text(-0.06323929665114071, -1.0981806733680344, 'JavaScript'),
#   Text(0.654413852726294, -0.8841620379545417, 'C#'),
#   Text(1.0520142924916651, -0.3213501647630839, 'C++')],
#  [Text(0.38857715625835565, 0.582243757917738, '31.3%'),
#   Text(-0.5530493062986165, 0.23267244100369752, '24.8%'),
#   Text(-0.43078333471945474, -0.41764305157393217, '12.4%'),
#   Text(-0.03449416180971311, -0.5990076400189277, '11.3%'),
#   Text(0.35695301057797857, -0.48227020252065905, '10.8%'),
#   Text(0.5738259777227264, -0.1752819080525912, '9.4%')])
