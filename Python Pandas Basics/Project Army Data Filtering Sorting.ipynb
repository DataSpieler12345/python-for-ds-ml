# %%
import pandas as pd

# %%
# Create an example dataframe about a fictional army
data = {'regiment': ['Nighthawks', 'Nighthawks', 'Nighthawks', 'Nighthawks', 'Dragoons', 'Dragoons', 'Dragoons', 'Dragoons', 'Scouts', 'Scouts', 'Scouts', 'Scouts'],
       		'company': ['1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd', '1st', '1st', '2nd', '2nd'],
       		'deaths': [523, 52, 25, 616, 43, 234, 523, 62, 62, 73, 37, 35],
       		'battles': [5, 42, 2, 2, 4, 7, 8, 3, 4, 7, 8, 9],
       		'size': [1045, 957, 1099, 1400, 1592, 1006, 987, 849, 973, 1005, 1099, 1523],
       		'veterans': [1, 5, 62, 26, 73, 37, 949, 48, 48, 435, 63, 345],
       		'readiness': [1, 2, 3, 3, 2, 1, 2, 3, 2, 1, 2, 3],
       		'armored': [1, 0, 1, 1, 0, 1, 0, 1, 0, 0, 1, 1],
       		'deserters': [4, 24, 31, 2, 3, 4, 24, 31, 2, 3, 2, 3],
       		'origin': ['Arizona', 'California', 'Texas', 'Florida', 'Maine', 'Iowa', 'Alaska', 'Washintong', 'Oregon', 'Wyoming', 'Lousina', 'Georgia']}

# %%
army = pd.DataFrame(data=data)
print(army)
# Out:
#       regiment company  deaths  battles  size  veterans  readiness  armored  \
# 0   Nighthawks     1st     523        5  1045         1          1        1
# 1   Nighthawks     1st      52       42   957         5          2        0
# 2   Nighthawks     2nd      25        2  1099        62          3        1
# 3   Nighthawks     2nd     616        2  1400        26          3        1
# 4     Dragoons     1st      43        4  1592        73          2        0
# 5     Dragoons     1st     234        7  1006        37          1        1
# 6     Dragoons     2nd     523        8   987       949          2        0
# 7     Dragoons     2nd      62        3   849        48          3        1
# 8       Scouts     1st      62        4   973        48          2        0
# 9       Scouts     1st      73        7  1005       435          1        0
# 10      Scouts     2nd      37        8  1099        63          2        1
# ...

# %% [markdown]
# ### Set the 'origin' column as the index of the dataframe

# %%
army.set_index('origin',inplace=True)
army
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washintong    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Lousina         Scouts     2nd      37        8  1099        63          2
# ...

# %% [markdown]
# ### Print only the column regiment and veterans

# %%
army.loc[:,['regiment','veterans']]
# Out:
#               regiment  veterans
# origin
# Arizona     Nighthawks         1
# California  Nighthawks         5
# Texas       Nighthawks        62
# Florida     Nighthawks        26
# Maine         Dragoons        73
# Iowa          Dragoons        37
# Alaska        Dragoons       949
# Washintong    Dragoons        48
# Oregon          Scouts        48
# Wyoming         Scouts       435
# Lousina         Scouts        63
# Georgia         Scouts       345

# %%
army[['regiment','veterans']] #anotherway
# Out:
#               regiment  veterans
# origin
# Arizona     Nighthawks         1
# California  Nighthawks         5
# Texas       Nighthawks        62
# Florida     Nighthawks        26
# Maine         Dragoons        73
# Iowa          Dragoons        37
# Alaska        Dragoons       949
# Washintong    Dragoons        48
# Oregon          Scouts        48
# Wyoming         Scouts       435
# Lousina         Scouts        63
# Georgia         Scouts       345

# %% [markdown]
# ### Print the columns 'veterans' and 'deaths'

# %%
army[['veterans','deaths']]
# Out:
#             veterans  deaths
# origin
# Arizona            1     523
# California         5      52
# Texas             62      25
# Florida           26     616
# Maine             73      43
# Iowa              37     234
# Alaska           949     523
# Washintong        48      62
# Oregon            48      62
# Wyoming          435      73
# Lousina           63      37
# Georgia          345      35

# %%
army.loc[:,['veterans','deaths']]
# Out:
#             veterans  deaths
# origin
# Arizona            1     523
# California         5      52
# Texas             62      25
# Florida           26     616
# Maine             73      43
# Iowa              37     234
# Alaska           949     523
# Washintong        48      62
# Oregon            48      62
# Wyoming          435      73
# Lousina           63      37
# Georgia          345      35

# %% [markdown]
# ### Select the 'deaths', 'size' and 'deserters' columns from origin Texas and Alaska

# %%
army.loc[['Texas','Alaska'],['deaths','size','deserters']]
# Out:
#         deaths  size  deserters
# origin
# Texas       25  1099         31
# Alaska     523   987         24

# %% [markdown]
# ### Select the rows 2 to 8 and the columns 3 to 7

# %%
army.iloc[2:8,3:7]
# Out:
#             battles  size  veterans  readiness
# origin
# Texas             2  1099        62          3
# Florida           2  1400        26          3
# Maine             4  1592        73          2
# Iowa              7  1006        37          1
# Alaska            8   987       949          2
# Washintong        3   849        48          3

# %% [markdown]
# ### Select every second row after the fourth row and all columns

# %%
army.iloc[4::2,:] #4 start / :: every second row / : all columns
# Out:
#          regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Maine    Dragoons     1st      43        4  1592        73          2
# Alaska   Dragoons     2nd     523        8   987       949          2
# Oregon     Scouts     1st      62        4   973        48          2
# Lousina    Scouts     2nd      37        8  1099        63          2
#
#          armored  deserters
# origin
# Maine          0          3
# Alaska         0         24
# Oregon         0          2
# Lousina        1          2

# %% [markdown]
# ### Select every row up to the 4th row and all columns

# %%
army.iloc[:4,:]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2

# %% [markdown]
# ### Select every 2nd row and every 2nd column

# %%
army.iloc[::2,::2]
# Out:
#            regiment  deaths  size  readiness  deserters
# origin
# Arizona  Nighthawks     523  1045          1          4
# Texas    Nighthawks      25  1099          3         31
# Maine      Dragoons      43  1592          2          3
# Alaska     Dragoons     523   987          2         24
# Oregon       Scouts      62   973          2          2
# Lousina      Scouts      37  1099          2          2

# %%
army.loc[::2,::2]
# Out:
#            regiment  deaths  size  readiness  deserters
# origin
# Arizona  Nighthawks     523  1045          1          4
# Texas    Nighthawks      25  1099          3         31
# Maine      Dragoons      43  1592          2          3
# Alaska     Dragoons     523   987          2         24
# Oregon       Scouts      62   973          2          2
# Lousina      Scouts      37  1099          2          2

# %%
army
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washintong    Dragoons     2nd      62        3   849        48          3
# Oregon          Scouts     1st      62        4   973        48          2
# Wyoming         Scouts     1st      73        7  1005       435          1
# Lousina         Scouts     2nd      37        8  1099        63          2
# ...

# %% [markdown]
# ### Select rows where deaths is greater than 100

# %%
army[army["deaths"] > 100]
# Out:
#            regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona  Nighthawks     1st     523        5  1045         1          1
# Florida  Nighthawks     2nd     616        2  1400        26          3
# Iowa       Dragoons     1st     234        7  1006        37          1
# Alaska     Dragoons     2nd     523        8   987       949          2
#
#          armored  deserters
# origin
# Arizona        1          4
# Florida        1          2
# Iowa           1          4
# Alaska         0         24

# %% [markdown]
# ### Select rows where deaths is greater than 500 or less than 50

# %%
army[(army['deaths'] > 500) | (army["deaths"] <50)]
# Out:
#            regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona  Nighthawks     1st     523        5  1045         1          1
# Texas    Nighthawks     2nd      25        2  1099        62          3
# Florida  Nighthawks     2nd     616        2  1400        26          3
# Maine      Dragoons     1st      43        4  1592        73          2
# Alaska     Dragoons     2nd     523        8   987       949          2
# Lousina      Scouts     2nd      37        8  1099        63          2
# Georgia      Scouts     2nd      35        9  1523       345          3
#
#          armored  deserters
# origin
# Arizona        1          4
# Texas          1         31
# Florida        1          2
# Maine          0          3
# Alaska         0         24
# Lousina        1          2
# Georgia        1          3

# %% [markdown]
# ### Select all the regiments not named "Scouts"

# %%
army[army['regiment'] != "Scouts"]
# Out:
#               regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Arizona     Nighthawks     1st     523        5  1045         1          1
# California  Nighthawks     1st      52       42   957         5          2
# Texas       Nighthawks     2nd      25        2  1099        62          3
# Florida     Nighthawks     2nd     616        2  1400        26          3
# Maine         Dragoons     1st      43        4  1592        73          2
# Iowa          Dragoons     1st     234        7  1006        37          1
# Alaska        Dragoons     2nd     523        8   987       949          2
# Washintong    Dragoons     2nd      62        3   849        48          3
#
#             armored  deserters
# origin
# Arizona           1          4
# California        0         24
# Texas             1         31
# Florida           1          2
# Maine             0          3
# Iowa              1          4
# Alaska            0         24
# ...

# %% [markdown]
# ### Select all the regiments named "Dragoons"

# %%
army[army['regiment'] == "Dragoons"]
# Out:
#             regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Maine       Dragoons     1st      43        4  1592        73          2
# Iowa        Dragoons     1st     234        7  1006        37          1
# Alaska      Dragoons     2nd     523        8   987       949          2
# Washintong  Dragoons     2nd      62        3   849        48          3
#
#             armored  deserters
# origin
# Maine             0          3
# Iowa              1          4
# Alaska            0         24
# Washintong        1         31

# %% [markdown]
# ### Select the rows called Texas and Arizona

# %%
army.loc[['Texas','Arizona'],:]
# Out:
#            regiment company  deaths  battles  size  veterans  readiness  \
# origin
# Texas    Nighthawks     2nd      25        2  1099        62          3
# Arizona  Nighthawks     1st     523        5  1045         1          1
#
#          armored  deserters
# origin
# Texas          1         31
# Arizona        1          4

# %% [markdown]
# ### Select the rows called Texas and Arizona and columns company and size

# %%
army.loc[['Texas','Arizona'],['company','size']]
# Out:
#         company  size
# origin
# Texas       2nd  1099
# Arizona     1st  1045
