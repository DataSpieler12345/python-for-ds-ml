# %%
import numpy as np
import pandas as pd

# %%
# name_of_df = pd.read_csv('filename.ext or file_path.ext')
new_df = pd.read_csv('animal.csv')
print('Data loaded')
new_df
# Out:
# Data loaded
#   Unnamed: 0 animal  age  visits priority
# 0          a    cat  2.5       1      yes
# 1          b    cat  3.0       3      yes
# 2          c  snake  0.5       2       no
# 3          d    dog  NaN       3      yes
# 4          e    dog  5.0       2       no
# 5          f    cat  1.5       3       no
# 6          g  snake  4.5       1       no
# 7          h    cat  NaN       1      yes
# 8          i    dog  7.0       2       no
# 9          j    dog  3.0       1       no

# %%
#you may get unicode error: add r or make all the back slases as forward

# %%
new_hp = pd.read_csv('E:\DATA SETS/KAGGLE/winequality-red.csv')
print('Data loaded')
new_hp
# Out:
# Data loaded
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#read an excel file
airpot_data = pd.read_excel('Airport_Data.xlsx')
print('Data loaded')
airpot_data
# Out:
# Data loaded
#      SiteNumber           Type LocationID EffectiveDate Region DistrictOffice  \
# 0      50009.*A        AIRPORT       'ADK     3/30/2017    AAL           NONE
# 1     50016.1*A        AIRPORT       'AKK     3/30/2017    AAL           NONE
# 2      50017.*A        AIRPORT       'Z13     3/30/2017    AAL           NONE
# 3     50017.1*C  SEAPLANE BASE       'KKI     3/30/2017    AAL           NONE
# 4      50020.*A        AIRPORT       'AKI     3/30/2017    AAL           NONE
# ..          ...            ...        ...           ...    ...            ...
# 746  50920.12*C  SEAPLANE BASE       '2Y3     3/30/2017    AAL           NONE
# 747    50920.*A        AIRPORT       'YAK     3/30/2017    AAL           NONE
# 748   50925.1*A        AIRPORT       'A77     3/30/2017    AAL           NONE
# 749    50928.*C  SEAPLANE BASE       '78K     3/30/2017    AAL           NONE
# 750    50990.*A        AIRPORT       'L20     3/30/2017    AAL           NONE
#
# ...

# %%
airpot_data.head()
# Out:
#   SiteNumber           Type LocationID EffectiveDate Region DistrictOffice  \
# 0   50009.*A        AIRPORT       'ADK     3/30/2017    AAL           NONE
# 1  50016.1*A        AIRPORT       'AKK     3/30/2017    AAL           NONE
# 2   50017.*A        AIRPORT       'Z13     3/30/2017    AAL           NONE
# 3  50017.1*C  SEAPLANE BASE       'KKI     3/30/2017    AAL           NONE
# 4   50020.*A        AIRPORT       'AKI     3/30/2017    AAL           NONE
#
#   State StateName          County CountyState  ... AirportPositionSource  \
# 0    AK    ALASKA  ALEUTIANS WEST          AK  ...      3RD PARTY SURVEY
# 1    AK    ALASKA   KODIAK ISLAND          AK  ...                  NACO
# 2    AK    ALASKA          BETHEL          AK  ...                 STATE
# 3    AK    ALASKA          BETHEL          AK  ...                   NaN
# 4    AK    ALASKA          BETHEL          AK  ...                 STATE
#
# ...

# %%
airpot_data[10:20]
# Out:
#     SiteNumber           Type LocationID EffectiveDate Region DistrictOffice  \
# 10   50027.6*A        AIRPORT      '4AK7     3/30/2017    AAL           NONE
# 11  50027.51*A        AIRPORT       'Z25     3/30/2017    AAL           NONE
# 12   50029.1*A        AIRPORT       '6A8     3/30/2017    AAL           NONE
# 13  50029.61*A        AIRPORT       'AFM     3/30/2017    AAL           NONE
# 14    50031.*A        AIRPORT       '80A     3/30/2017    AAL           NONE
# 15   50031.5*C  SEAPLANE BASE      'AK81     3/30/2017    AAL           NONE
# 16    50032.*A        AIRPORT       'AKP     3/30/2017    AAL           NONE
# 17   50037.3*A        AIRPORT      'AK00     3/30/2017    AAL           NONE
# 18  50037.31*A        AIRPORT      '00AK     3/30/2017    AAL           NONE
# 19   50033.1*H       HELIPORT       '2OK     3/30/2017    AAL           NONE
#
#    State StateName            County CountyState  ... AirportPositionSource  \
# ...

# %%
#check the columns of the data frame
airpot_data.columns
# Out:
# Index(['SiteNumber', 'Type', 'LocationID', 'EffectiveDate', 'Region',
#        'DistrictOffice', 'State', 'StateName', 'County', 'CountyState',
#        ...
#        'AirportPositionSource', 'AirportPositionSourceDate',
#        'AirportElevationSource', 'AirportElevationSourceDate',
#        'ContractFuelAvailable', 'TransientStorage', 'OtherServices',
#        'WindIndicator', 'IcaoIdentifier', 'BeaconSchedule2'],
#       dtype='object', length=103)

# %%
airpot_data.index #index
# Out:
# RangeIndex(start=0, stop=751, step=1)

# %%
airpot_data.tail() #last rows of the data set
# Out:
#      SiteNumber           Type LocationID EffectiveDate Region DistrictOffice  \
# 746  50920.12*C  SEAPLANE BASE       '2Y3     3/30/2017    AAL           NONE
# 747    50920.*A        AIRPORT       'YAK     3/30/2017    AAL           NONE
# 748   50925.1*A        AIRPORT       'A77     3/30/2017    AAL           NONE
# 749    50928.*C  SEAPLANE BASE       '78K     3/30/2017    AAL           NONE
# 750    50990.*A        AIRPORT       'L20     3/30/2017    AAL           NONE
#
#     State StateName             County CountyState  ... AirportPositionSource  \
# 746    AK    ALASKA    SKAGWAY-YAKUTAT          AK  ...               FAA-EST
# 747    AK    ALASKA    SKAGWAY-YAKUTAT          AK  ...      3RD PARTY SURVEY
# 748    AK    ALASKA          KUSKOKWIM          AK  ...                   NaN
# 749    AK    ALASKA  KETCHIKAN GATEWAY          AK  ...                   NaN
# 750    AK    ALASKA        UPPER YUKON          AK  ...               FAA-EST
#
# ...

# %%
# write df as csv or excel
airpot_data.to_csv('airpot_data_pandas_df')
print('File created')
# Out:
# File created

# %%
airpot_data.to_csv('airpot_data_pandas_df.csv')
print('CSV File created')
# Out:
# CSV File created
