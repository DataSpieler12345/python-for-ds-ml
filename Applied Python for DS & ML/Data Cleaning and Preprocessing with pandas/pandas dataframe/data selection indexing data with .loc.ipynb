# %% [markdown]
# <center><h1><b><font size="5">Pandas DataFrames: Data Selection - Indexing Data with .loc[]</font></b></h1></center>

# %% [markdown]
# #### Import pandas

# %%
import pandas as pd

# %% [markdown]
# #### Load the data

# %%
data = pd.read_csv('./data/Lending-company.csv', index_col = 'LoanID')
lending_co_data = data.copy()
lending_co_data.head()
# Out:
#         StringID    Product CustomerGender     Location    Region  TotalPrice  \
# LoanID
# 1       LoanID_1  Product B         Female   Location 3  Region 2     17600.0
# 2       LoanID_2  Product D         Female   Location 6  Region 6         NaN
# 3       LoanID_3  Product B           Male   Location 8  Region 3     16600.0
# 4       LoanID_4  Product A           Male  Location 26  Region 2     17600.0
# 5       LoanID_5  Product B         Female  Location 34  Region 3     21250.0
#
#          StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  AmtPaid60  \
# LoanID
# 1       04/07/2018     2200         45          365       3221       4166
# 2       02/01/2019     2200         45          365       3161       4096
# 3       08/12/2016     1000         45          365       2260       3205
# 4              NaN     2200         45          365       3141       4166
# 5       28/10/2017     2200         55          365       3570       4745
#
#         AmtPaid360 LoanStatus
# ...

# %%
lending_co_data
# Out:
#                Product CustomerGender     Location    Region  TotalPrice  \
# StringID
# LoanID_1     Product B         Female   Location 3  Region 2     17600.0
# LoanID_2     Product D         Female   Location 6  Region 6         NaN
# LoanID_3     Product B           Male   Location 8  Region 3     16600.0
# LoanID_4     Product A           Male  Location 26  Region 2     17600.0
# LoanID_5     Product B         Female  Location 34  Region 3     21250.0
# ...                ...            ...          ...       ...         ...
# LoanID_1039  Product B           Male  Location 73  Region 6     17300.0
# LoanID_1040  Product A           Male  Location 82  Region 1         NaN
# LoanID_1041  Product A   NotSpecified  Location 11  Region 4     17300.0
# LoanID_1042  Product B         Female  Location 26  Region 6     16300.0
# LoanID_1043  Product A   NotSpecified  Location 94  Region 6     17300.0
#
#               StartDate  Deposit  DailyRate  TotalDaysYr  AmtPaid36  \
# StringID
# ...

# %%
lending_co_data.loc['LoanID_3']
# Out:
# Product            Product B
# CustomerGender          Male
# Location          Location 8
# Region              Region 3
# TotalPrice           16600.0
# StartDate         08/12/2016
# Deposit                 1000
# DailyRate                 45
# TotalDaysYr              365
# AmtPaid36               2260
# AmtPaid60               3205
# AmtPaid360             16340
# LoanStatus               NaN
# Name: LoanID_3, dtype: object

# %%
lending_co_data.loc['LoanID_3', :]
# Out:
# Product            Product B
# CustomerGender          Male
# Location          Location 8
# Region              Region 3
# TotalPrice           16600.0
# StartDate         08/12/2016
# Deposit                 1000
# DailyRate                 45
# TotalDaysYr              365
# AmtPaid36               2260
# AmtPaid60               3205
# AmtPaid360             16340
# LoanStatus               NaN
# Name: LoanID_3, dtype: object

# %%
lending_co_data.loc['LoanID_3', 'Region']
# Out:
# 'Region 3'

# %%
lending_co_data['Location']
# Out:
# StringID
# LoanID_1        Location 3
# LoanID_2        Location 6
# LoanID_3        Location 8
# LoanID_4       Location 26
# LoanID_5       Location 34
#                   ...
# LoanID_1039    Location 73
# LoanID_1040    Location 82
# LoanID_1041    Location 11
# LoanID_1042    Location 26
# LoanID_1043    Location 94
# Name: Location, Length: 1043, dtype: object

# %%
lending_co_data.loc['Location'] #error Locations

# %%
lending_co_data.loc[:,'Location']
# Out:
# StringID
# LoanID_1        Location 3
# LoanID_2        Location 6
# LoanID_3        Location 8
# LoanID_4       Location 26
# LoanID_5       Location 34
#                   ...
# LoanID_1039    Location 73
# LoanID_1040    Location 82
# LoanID_1041    Location 11
# LoanID_1042    Location 26
# LoanID_1043    Location 94
# Name: Location, Length: 1043, dtype: object

# %%
lending_co_data.loc[:,'Locations'] # Error Locations
