# %% [markdown]
# #### Importing Data
#
# * https://www.kaggle.com/datasets/uciml/iris
# * http://archive.ics.uci.edu/ml/datasets/Iris

# %%
import pandas as pd

# %% [markdown]
# #### CSV File

# %%
#Store the dataFrame into a variable
df = pd.read_csv("E:\DATA SETS\Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
# redefine the index column with Id
df.set_index("Id")
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
#check if are changed if not fix it...
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.set_index("Id", inplace=True)

# %%
df.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %%
# another way when importing data
df = pd.read_csv("E:\DATA SETS\Iris.csv", index_col=0)
df.head()
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa

# %% [markdown]
# #### Excel File

# %%
# !pip install openpyxl

# %%
import openpyxl

# %%
df = pd.read_excel("E:\DATA SETS\Iris.xlsx", index_col=0)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1               51            35             14             2     Iris-setosa
# 2               49            30             14             2     Iris-setosa
# 3               47            32             13             2     Iris-setosa
# 4               46            31             15             2     Iris-setosa
# 5               50            36             14             2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146             67            30             52            23  Iris-virginica
# 147             63            25             50            19  Iris-virginica
# 148             65            30             52            20  Iris-virginica
# 149             62            34             54            23  Iris-virginica
# 150             59            30             51            18  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### file.data

# %%
pd.read_table("E:\DATA SETS\iris.data",
              sep=",", 
              header=None,
              names=['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm', 'Species'] #columns
             )
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# The pd.read_clipboard() function is used to read data from the table that has been copied to the clipboard.
pd.read_clipboard()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1             51            35             14             2  Iris-setosa
# 1   2             49            30             14             2  Iris-setosa
# 2   3             47            32             13             2  Iris-setosa

# %% [markdown]
# #### HTML Pages

# %%
# !pip install lxml

# %%
import lxml

# %%
# !pip show lxml
# Out:
# Name: lxml
# Version: 4.9.2
# Summary: Powerful and Pythonic XML processing library combining libxml2/libxslt with the ElementTree API.
# Home-page: https://lxml.de/
# Author: lxml dev team
# Author-email: lxml-dev@lxml.de
# License: BSD-3-Clause
# Location: e:\python bildung\python mini e_degre\masterenv\lib\site-packages
# Requires:
# Required-by:

# %%
pd.read_clipboard()
# Out:
# Empty DataFrame
# Columns: [https://en.wikipedia.org/wiki/Timeline_of_programming_languages]
# Index: []

# %%
dfs = pd.read_html('https://en.wikipedia.org/wiki/Timeline_of_programming_languages')

# %%
type(dfs)
# Out:
# list

# %%
dfs[5]
# Out:
#        Year                                          Name  \
# 0      1950                     Short Code (for UNIVAC I)
# 1      1951                                     Superplan
# 2      1951                                         ALGAE
# 3      1951             Intermediate Programming Language
# 4      1951                   Boehm unnamed coding system
# 5      1951                              Klammerausdrücke
# 6      1951                         Stanislaus (Notation)
# 7      1951                          Sort Merge Generator
# 8      1952                    Short Code (for UNIVAC II)
# 9      1952                                           A-0
# 10     1952                              Glennie Autocode
# 11     1952                          Operator programming
# 12     1952                             Editing Generator
# 13     1952                                       COMPOOL
# 14     1953                                   Speedcoding
# ...

# %%
dfs[7]
# Out:
#      Year                                          Name  \
# 0    1970                        Forth (implementation)
# 1    1970                                         POP-2
# 2    1970                                          SAIL
# 3    1970                                        Pascal
# 4    1970                                         BLISS
# 5    1971                                           KRL
# 6    1971           Compiler Description Language (CDL)
# 7    1972                                  Smalltalk-72
# 8    1972                                          PL/M
# 9    1972                                             C
# 10   1972                                      INTERCAL
# 11   1972                                        Prolog
# 12   1972               Structured Query language (SQL)
# 13   1973                                         COMAL
# 14   1973                                            ML
# 15   1973                                           LIS
# ...

# %%
dfs[6]
# Out:
#      Year                                           Name  \
# 0    1960                                       ALGOL 60
# 1    1960                      COBOL 61 (implementation)
# 2    1961                         COMIT (implementation)
# 3    1961                                           GPSS
# 4    1962                                     FORTRAN IV
# 5    1962                                  APL (concept)
# 6    1962                               Simula (concept)
# 7    1962                                         SNOBOL
# 8    1963  Combined Programming Language (CPL) (concept)
# 9    1963                                        SNOBOL3
# 10   1963                             ALGOL 68 (concept)
# 11   1963                                         JOSS I
# 12   1964                                          MIMIC
# 13   1964                                         COWSEL
# 14   1964                                 PL/I (concept)
# ...

# %%
dfs[4]
# Out:
#       Year                                         Name  \
# 0     1804                             Jacquard machine
# 1     1879                              Begriffsschrift
# 2  1943–45       Plankalkül (year of conceptualization)
# 3  1943–46                          ENIAC coding system
# 4     1946                             ENIAC Short Code
# 5  1947-52                       ARC/Birkbeck Assembler
# 6     1948     Plankalkül (year of concept publication)
# 7     1949                         EDSAC Initial Orders
# 8     1949  Short Code (originally known as Brief Code)
# 9     Year                                         Name
#
#                             Chief developer, company          Predecessor(s)
# 0                              Joseph Marie Jacquard  none (unique language)
# 1                                      Gottlob Frege  none (unique language)
# 2                                        Konrad Zuse  none (unique language)
# ...

# %%
dfs[8]
# Out:
#        Year                       Name  \
# 0      1980      Ada 80 (MIL-STD-1815)
# 1      1980             C with classes
# 2      1980              Applesoft III
# 3      1980  Apple III Microsoft BASIC
# 4   1980–81                     CBASIC
# ..      ...                        ...
# 63     1989                     VisSim
# 64     1989                        LPC
# 65     1989                       Bash
# 66     1989                      Magik
# 67     Year                       Name
#
#                     Chief developer, company  \
# 0         Jean Ichbiah at CII Honeywell Bull
# 1                       Bjarne Stroustrup[6]
# 2                             Apple Computer
# 3                                  Microsoft
# 4                             Gordon Eubanks
# ..                                       ...
# 63           Peter Darnell, Visual Solutions
# 64                               Lars Pensjö
# 65                                 Brian Fox
# ...

# %%
dfs[9]
# Out:
#     Year                       Name  \
# 0   1990                     Sather
# 1   1990                 AMOS BASIC
# 2   1990                       AMPL
# 3   1990              Object Oberon
# 4   1990                          J
# ..   ...                        ...
# 69  1999                        C99
# 70  1999                     Gambas
# 71  1999  Game Maker Language (GML)
# 72  1999                    Harbour
# 73  Year                       Name
#
#                              Chief developer, company      Predecessor(s)
# 0                                     Steve Omohundro              Eiffel
# 1         François Lionet and Constantin Sotiropoulos          STOS BASIC
# 2   Robert Fourer, David Gay and Brian Kernighan a...                 NaN
# 3                  H Mössenböck, J Templ, R Griesemer              Oberon
# 4   Kenneth E. Iverson, Roger Hui at Iverson Software             APL, FP
# ..                                                ...                 ...
# ...

# %%
dfs[10]
# Out:
#     Year                                 Name  \
# 0   2000                            Join Java
# 1   2000                            DarkBASIC
# 2   2000                                   C#
# 3   2001                                  Joy
# 4   2001                              AspectJ
# 5   2001                                    D
# 6   2001                           Processing
# 7   2001                    Visual Basic .NET
# 8   2001                       GDScript (GDS)
# 9   2001     Shakespeare Programming Language
# 10  2002                                   Io
# 11  2002                                 Gosu
# 12  2002                              Scratch
# 13  2003                              Nemerle
# 14  2003                               Factor
# 15  2003                                Scala
# 16  2003                                C++03
# 17  2003                             Squirrel
# 18  2003                                  Boo
# ...

# %%
dfs[11]
# Out:
#     Year          Name                           Chief developer, company  \
# 0   2010          Rust                             Graydon Hoare, Mozilla
# 1   2011           C11                              C11 ISO/IEC 9899:2011
# 2   2011        Ceylon                                Gavin King, Red Hat
# 3   2011          Dart                                             Google
# 4   2011         C++11                             C++ ISO/IEC 14882:2011
# 5   2011        Kotlin                                          JetBrains
# 6   2011           Red                                    Nenad Rakočević
# 7   2011           Opa                                            MLstate
# 8   2012        Elixir                                         José Valim
# 9   2012           Elm                                     Evan Czaplicki
# 10  2012    TypeScript                        Anders Hejlsberg, Microsoft
# 11  2012         Julia  Jeff Bezanson, Stefan Karpinski, Viral Shah, A...
# ...

# %% [markdown]
# #### Reading SQL DB

# %%
import sqlite3

# %%
con = sqlite3.connect("E:\DATA SETS\database.sqlite")
df = pd.read_sql_query('select * from iris', con)
con.close()

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...
