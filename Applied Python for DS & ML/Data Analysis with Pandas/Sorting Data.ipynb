# %%
import pandas as pd

# %%
df = pd.read_excel("E:\DATA SETS\Iris_mini.xlsx", index_col=0)
df
# Out:
#     SL  SW  PL  PW          Species
# Id
# A   51  35  14   2      Iris-setosa
# B   49  30  14   2      Iris-setosa
# C   70  32  47  14  Iris-versicolor
# D   64  32  45  15  Iris-versicolor
# E   63  33  60  25   Iris-virginica
# F   58  27  51  19   Iris-virginica

# %%
# sort the values of SL column
df.sort_values("SL")
# Out:
#     SL  SW  PL  PW          Species
# Id
# B   49  30  14   2      Iris-setosa
# A   51  35  14   2      Iris-setosa
# F   58  27  51  19   Iris-virginica
# E   63  33  60  25   Iris-virginica
# D   64  32  45  15  Iris-versicolor
# C   70  32  47  14  Iris-versicolor

# %%
df.sort_values("SL", ascending=False)
# Out:
#     SL  SW  PL  PW          Species
# Id
# C   70  32  47  14  Iris-versicolor
# D   64  32  45  15  Iris-versicolor
# E   63  33  60  25   Iris-virginica
# F   58  27  51  19   Iris-virginica
# A   51  35  14   2      Iris-setosa
# B   49  30  14   2      Iris-setosa

# %%
# same but with multi values
df.sort_values(["PL","SL"], ascending=False)
# Out:
#     SL  SW  PL  PW          Species
# Id
# E   63  33  60  25   Iris-virginica
# F   58  27  51  19   Iris-virginica
# C   70  32  47  14  Iris-versicolor
# D   64  32  45  15  Iris-versicolor
# A   51  35  14   2      Iris-setosa
# B   49  30  14   2      Iris-setosa

# %%
#PL column will be sorted as desc and the PL as desc
df.sort_values(["PL","SL"], ascending=[False,False])
# Out:
#     SL  SW  PL  PW          Species
# Id
# E   63  33  60  25   Iris-virginica
# F   58  27  51  19   Iris-virginica
# C   70  32  47  14  Iris-versicolor
# D   64  32  45  15  Iris-versicolor
# A   51  35  14   2      Iris-setosa
# B   49  30  14   2      Iris-setosa

# %%
df.sort_index()
# Out:
#     SL  SW  PL  PW          Species
# Id
# A   51  35  14   2      Iris-setosa
# B   49  30  14   2      Iris-setosa
# C   70  32  47  14  Iris-versicolor
# D   64  32  45  15  Iris-versicolor
# E   63  33  60  25   Iris-virginica
# F   58  27  51  19   Iris-virginica

# %%
df["SL"].sort_values(ascending=False)
# Out:
# Id
# C    70
# D    64
# E    63
# F    58
# A    51
# B    49
# Name: SL, dtype: int64
