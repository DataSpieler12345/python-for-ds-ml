# %% [markdown]
# <center><h1><b><font size="5">The Hitters Dataset: Preprocessing and Preparation</font></b></h1></center>

# %% [markdown]
# #### Importing the Libraries

# %%
import pandas as pd
import numpy as np 
import math
import matplotlib.pyplot as plt
import seaborn as sns 
sns.set()

from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import LassoCV

from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Load the data

# %%
data = pd.read_csv('./data/Hitters.csv')
data.head()
# Out:
#    AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  CRuns  \
# 0    293    66      1    30   29     14      1     293     66       1     30
# 1    315    81      7    24   38     39     14    3449    835      69    321
# 2    479   130     18    66   72     76      3    1624    457      63    224
# 3    496   141     20    65   78     37     11    5628   1575     225    828
# 4    321    87     10    39   42     30      2     396    101      12     48
#
#    CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary NewLeague
# 0    29      14      A        E      446       33      20     NaN         A
# 1   414     375      N        W      632       43      10   475.0         N
# 2   266     263      A        W      880       82      14   480.0         A
# 3   838     354      N        E      200       11       3   500.0         N
# 4    46      33      N        E      805       40       4    91.5         N

# %% [markdown]
# #### make a copy of the original DF

# %%
df_hitters = data.copy()
df_hitters
#Salary target variable = predict a baseball players salary based on the rest of the features
# Out:
#      AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  \
# 0      293    66      1    30   29     14      1     293     66       1
# 1      315    81      7    24   38     39     14    3449    835      69
# 2      479   130     18    66   72     76      3    1624    457      63
# 3      496   141     20    65   78     37     11    5628   1575     225
# 4      321    87     10    39   42     30      2     396    101      12
# ..     ...   ...    ...   ...  ...    ...    ...     ...    ...     ...
# 317    497   127      7    65   48     37      5    2703    806      32
# 318    492   136      5    76   50     94     12    5511   1511      39
# 319    475   126      3    61   43     52      6    1700    433       7
# 320    573   144      9    85   60     78      8    3198    857      97
# 321    631   170      9    77   44     31     11    4908   1457      30
#
#      CRuns  CRBI  CWalks League Division  PutOuts  Assists  Errors  Salary  \
# 0       30    29      14      A        E      446       33      20     NaN
# 1      321   414     375      N        W      632       43      10   475.0
# 2      224   266     263      A        W      880       82      14   480.0
# 3      828   838     354      N        E      200       11       3   500.0
# 4       48    46      33      N        E      805       40       4    91.5
# ..     ...   ...     ...    ...      ...      ...      ...     ...     ...
# 317    379   311     138      N        E      325        9       3   700.0
# 318    897   451     875      A        E      313      381      20   875.0
# 319    217    93     146      A        W       37      113       7   385.0
# 320    470   420     332      A        E     1314      131      12   960.0
# 321    775   357     249      A        W      408        4       3  1000.0
#
#     NewLeague
# 0           A
# 1           N
# 2           A
# 3           N
# 4           N
# ..        ...
# 317         N
# 318         A
# 319         A
# 320         A
# 321         A
#
# [322 rows x 20 columns]

# %% [markdown]
# #### Categorical Variables

# %%
print('The league types are:', df_hitters['League'].unique())
print('The division types are:', df_hitters['Division'].unique())
print('The new league options are:', df_hitters['NewLeague'].unique())
# Out:
# The league types are: ['A' 'N']
# The division types are: ['E' 'W']
# The new league options are: ['A' 'N']

# %% [markdown]
# #### Converts categorical variables into 0s and 1s

# %%
df_hitters_num = pd.get_dummies(df_hitters, columns = ['League', 'Division', 'NewLeague'], drop_first=True)
df_hitters_num
# Out:
#      AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  \
# 0      293    66      1    30   29     14      1     293     66       1
# 1      315    81      7    24   38     39     14    3449    835      69
# 2      479   130     18    66   72     76      3    1624    457      63
# 3      496   141     20    65   78     37     11    5628   1575     225
# 4      321    87     10    39   42     30      2     396    101      12
# ..     ...   ...    ...   ...  ...    ...    ...     ...    ...     ...
# 317    497   127      7    65   48     37      5    2703    806      32
# 318    492   136      5    76   50     94     12    5511   1511      39
# 319    475   126      3    61   43     52      6    1700    433       7
# 320    573   144      9    85   60     78      8    3198    857      97
# 321    631   170      9    77   44     31     11    4908   1457      30
#
#      CRuns  CRBI  CWalks  PutOuts  Assists  Errors  Salary  League_N  \
# 0       30    29      14      446       33      20     NaN     False
# 1      321   414     375      632       43      10   475.0      True
# 2      224   266     263      880       82      14   480.0     False
# 3      828   838     354      200       11       3   500.0      True
# 4       48    46      33      805       40       4    91.5      True
# ..     ...   ...     ...      ...      ...     ...     ...       ...
# 317    379   311     138      325        9       3   700.0      True
# 318    897   451     875      313      381      20   875.0     False
# 319    217    93     146       37      113       7   385.0     False
# 320    470   420     332     1314      131      12   960.0     False
# 321    775   357     249      408        4       3  1000.0     False
#
#      Division_W  NewLeague_N
# 0         False        False
# 1          True         True
# 2          True        False
# 3         False         True
# 4         False         True
# ..          ...          ...
# 317       False         True
# 318       False        False
# 319        True        False
# 320       False        False
# 321        True        False
#
# [322 rows x 20 columns]

# %% [markdown]
# #### Checking NaN values

# %%
df_hitters_num.isnull().sum()
# Out:
# AtBat           0
# Hits            0
# HmRun           0
# Runs            0
# RBI             0
# Walks           0
# Years           0
# CAtBat          0
# CHits           0
# CHmRun          0
# CRuns           0
# CRBI            0
# CWalks          0
# PutOuts         0
# Assists         0
# Errors          0
# Salary         59
# League_N        0
# Division_W      0
# NewLeague_N     0
# dtype: int64

# %% [markdown]
# #### Fill NaNs with predicted values

# %%
df_hitters_num_nonull = df_hitters_num.dropna()
df_hitters_num_nonull.isnull().sum()
# Out:
# AtBat          0
# Hits           0
# HmRun          0
# Runs           0
# RBI            0
# Walks          0
# Years          0
# CAtBat         0
# CHits          0
# CHmRun         0
# CRuns          0
# CRBI           0
# CWalks         0
# PutOuts        0
# Assists        0
# Errors         0
# Salary         0
# League_N       0
# Division_W     0
# NewLeague_N    0
# dtype: int64

# %%
numeric_df = df_hitters.select_dtypes(include='number')

# %%
# check for multicolinearity
plt.figure(figsize=(13,6))
sns.heatmap(numeric_df.corr(),
            vmin = -1,
            vmax = 1,
            cmap = "GnBu",
            annot=True)
plt.show()

# %% [markdown]
# <center><h1><b><font size="5">Exploratory Data Analysis</font></b></h1></center>

# %% [markdown]
# #### Plot salary from df_hitter_num_nonull

# %%
sns.displot(df_hitters_num_nonull['Salary']);

# %% [markdown]
# #### Check the relationship of  dependent and the independent variable in the dataset

# %%
correlation = df_hitters_num_nonull.corr()
correlation['Salary'].sort_values(ascending=True)
#salaray = dependent variable 
# the others one are independent variables
# pearson correlation ( 1 stron positive correlation / -1 strong negative correlation / 0 there is no relationship)
# Out:
# Division_W    -0.192514
# League_N      -0.014282
# Errors        -0.005401
# NewLeague_N   -0.002834
# Assists        0.025436
# PutOuts        0.300480
# HmRun          0.343028
# AtBat          0.394771
# Years          0.400657
# Runs           0.419859
# Hits           0.438675
# Walks          0.443867
# RBI            0.449457
# CWalks         0.489822
# CHmRun         0.524931
# CAtBat         0.526135
# CHits          0.548910
# CRuns          0.562678
# CRBI           0.566966
# Salary         1.000000
# Name: Salary, dtype: float64

# %% [markdown]
# #### Declare the dependent and independent variables

# %%
X = df_hitters_num_nonull.drop('Salary', axis = 1)
y = df_hitters_num_nonull['Salary']

# %% [markdown]
# #### Split the data into train and test sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state = 365)

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# #### Perform linear regression

# %%
lin_reg = LinearRegression()
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("Linear Regression coefficients are: ", lin_reg.coef_)
print("Linear Regression y-intercept is: ", lin_reg.intercept_)
# Out:
# Linear Regression coefficients are:  [-216.58725574  176.6665394    26.42174341  -32.30723397    3.50396442
#   114.47871878  -38.27993316 -900.68020534  836.55817419   28.55520441
#   405.6848943    64.99526588 -187.22476547  115.53995185   68.62131273
#   -13.90111177   58.90973857  -81.77905186  -35.02755069]
# Linear Regression y-intercept is:  532.2961176470588

# %% [markdown]
# #### create a new variable

# %%
lin_reg_y_pred = lin_reg.predict(X_test)
lin_reg_y_pred
# Out:
# array([ 415.45782829,  432.20780272,  758.78349674,  799.00336712,
#         350.20586478,  294.0659682 ,  184.24872446,  464.67402835,
#        1108.05429466,  556.19984654,  488.06923001,  473.30471499,
#         839.99519038,  751.59519044,  220.43742205,  320.16591592,
#         340.14473675,  710.61012663,  170.8874789 ,  651.78620649,
#         827.41281464,  196.71008612,  573.1185691 , 1172.76382687,
#        1282.0883485 , 1594.28681356,  777.07655701, 1094.24965368,
#         556.76207246, 1107.0708847 ,  477.61394579,  297.87571483,
#         361.26177051,  503.18848321,  189.99424369,  241.50466799,
#         248.98173212,  942.76631923,  617.30294655,  225.25956752,
#         323.42092736,  455.93050456,  871.9585369 ,  379.23514877,
#         620.49084963,  281.78622042,  566.78476943,  589.94187243,
#         662.63913511,  545.01484672, 2012.42953081,  737.55139652,
#         380.02427287,  443.3775693 , 1076.912394  ,  710.95238727,
#         556.2946056 ,   68.23384264,  209.15575371,  195.57359992,
#         678.8504475 ,  487.81690665,  543.73138812,  573.85230894,
#        1039.02772566,  433.67748284,  266.36020342,  667.87240365,
#         268.47739563,  411.94624022,  564.76045065,  292.76931502,
#         100.65898566,  824.41983576,  398.60360551,  525.16278803,
#         547.37462319,  292.19862598,  545.54429843,  570.69007962,
#         485.80650805,  509.57385645,  209.18317076,  159.06793297,
#         456.63214183,  440.45455683,  841.60950892,  592.35681405,
#         422.50193249,  383.90545132,  115.77851116,  315.35230911,
#         911.32219661])

# %% [markdown]
# #### Compre the predicted values with the actual ones

# %%
#create a DF containing the results
lin_comp = pd.DataFrame({'Predicted': lin_reg_y_pred, 'Actual': y_test})
lin_comp
# Out:
#       Predicted  Actual
# 14   415.457828   240.0
# 181  432.207803   737.5
# 177  758.783497  1300.0
# 124  799.003367   737.5
# 277  350.205865   475.0
# ..          ...     ...
# 303  422.501932   425.0
# 264  383.905451   250.0
# 31   115.778511   110.0
# 204  315.352309   780.0
# 84   911.322197  1900.0
#
# [93 rows x 2 columns]

# %% [markdown]
# #### Performing Linear Regression

# %%
print("Linear Regression Model RMSE is: ", math.sqrt(mean_squared_error(y_test, lin_reg_y_pred)))
print("Linear Regression Model Training Score: ", lin_reg.score(X_train, y_train))
print("Linear Regression Model Testing Score: ", lin_reg.score(X_test, y_test))
# Out:
# Linear Regression Model RMSE is:  313.23956789940615
# Linear Regression Model Training Score:  0.5680589160518967
# Linear Regression Model Testing Score:  0.34559948297363363

# %% [markdown]
# #### Performing Ridge Regression with Cross-validation

# %%
cv = RepeatedKFold(n_splits=5, n_repeats=3, random_state=1)

# %%
ridge = RidgeCV(alphas=np.arange(0.1, 10, 0.1), cv=cv, scoring='neg_mean_squared_error')

# %%
ridge.fit(X_train, y_train)
ridge_reg_y_pred = ridge.predict(X_test)

print("Ridge tuning parameter:", (ridge.alpha_))
print("Ridge model cofficients:", (ridge.coef_))
print("Ridge model intercept:", (ridge.intercept_))
# Out:
# Ridge tuning parameter: 9.9
# Ridge model cofficients: [ -99.64056512   87.85475144   -3.70978058   22.50316688   18.34973213
#    68.1928924   -55.21554926   -5.93096462  127.21511684   21.56457876
#   129.7438877    93.22509485 -102.97057988  116.56925232   31.19052366
#   -10.05599857   39.05110375  -80.7269112   -22.53792401]
# Ridge model intercept: 532.2961176470588

# %%
print("Ridge Regression Model RMSE is: ", math.sqrt(mean_squared_error(y_test, ridge_reg_y_pred)))
print("Ridge Regression Model Training Score: ", ridge.score(X_train, y_train))
print("Ridge Regression Model Testing Score: ", ridge.score(X_test, y_test))
# Out:
# Ridge Regression Model RMSE is:  288.62308325272807
# Ridge Regression Model Training Score:  0.5278667721769685
# Ridge Regression Model Testing Score:  0.4444124247349731

# %% [markdown]
# #### Performing Lasso Regresion with Cross-validation
#
# Lasso regression decreases the coefficients values in a way that the least significant of them can fall all the way to 0

# %%
lasso = LassoCV(alphas=np.arange(0.1, 10, 0.1), cv=cv, tol=1) # 1 to prevents dualiuty gap and #tol = optimization tolerance tell the algorithm to stop searching once the tolerance between minimum and maximum is achieved

# %%
lasso.fit(X_train, y_train)
lasso_reg_y_pred = lasso.predict(X_test)

print("Lasso tuning parameter:", (lasso.alpha_))
print("Lasso model cofficients:", (lasso.coef_))
print("Lasso model intercept:", (lasso.intercept_))
# Out:
# Lasso tuning parameter: 8.2
# Lasso model cofficients: [ 55.51095192  45.97703489  27.53137446   3.3631333    9.03843356
#   49.43671419 126.70293106  45.10058938  23.05442632   9.85632406
#    0.           3.15689767  -8.11886084 102.94992196   0.
#   -0.          17.76359236 -85.73614642  -0.        ]
# Lasso model intercept: 532.2961176470588

# %%
print("Lasso Regression Model RMSE is: ", math.sqrt(mean_squared_error(y_test, lasso_reg_y_pred)))
print("Lasso Regression Model Training Score: ", lasso.score(X_train, y_train))
print("Lasso Regression Model Testing Score: ", lasso.score(X_test, y_test))
# Out:
# Lasso Regression Model RMSE is:  304.2072505265753
# Lasso Regression Model Training Score:  0.4482426197173428
# Lasso Regression Model Testing Score:  0.3827948756282943

# %% [markdown]
# <center><h1><b><font size="5">Compare the Scores</font></b></h1></center>

# %%
print("Linear Regression Model Training Score: ", lin_reg.score(X_train, y_train)) #highes value
print("Linear Regression Model Testing Score: ", lin_reg.score(X_test, y_test)) #Only 35% of the data managed to fit the model properly

print("Ridge Regression Model Training Score: ", ridge.score(X_train, y_train))
print("Ridge Regression Model Testing Score: ", ridge.score(X_test, y_test))

print("Lasso Regression Model Training Score: ", lasso.score(X_train, y_train))
print("Lasso Regression Model Testing Score: ", lasso.score(X_test, y_test))
# Out:
# Linear Regression Model Training Score:  0.5680589160518967
# Linear Regression Model Testing Score:  0.34559948297363363
# Ridge Regression Model Training Score:  0.5278667721769685
# Ridge Regression Model Testing Score:  0.4444124247349731
# Lasso Regression Model Training Score:  0.4482426197173428
# Lasso Regression Model Testing Score:  0.3827948756282943

# %% [markdown]
# <center><h1><b><font size="5">Compare the root mean squared error | RMSE</font></b></h1></center>

# %%
print("Linear Regression Model RMSE is: ", math.sqrt(mean_squared_error(y_test, lin_reg_y_pred)))
#the average distance between predicted and actual values is shortest when applying ridge regression
print("Ridge Regression Model RMSE is: ", math.sqrt(mean_squared_error(y_test, ridge_reg_y_pred))) 

print("asso Regression Model RMSE is: ", math.sqrt(mean_squared_error(y_test, lasso_reg_y_pred)))
# Out:
# Linear Regression Model RMSE is:  313.23956789940615
# Ridge Regression Model RMSE is:  288.62308325272807
# asso Regression Model RMSE is:  304.2072505265753

# %% [markdown]
# #### Conclusion
#  **Ridge** and **Lasso** handle the data better than the linear regression
#
#  In this case **Ridge Regression** is the properly algorithm
#
#  It is essential to understand the data and what problem you are facin in order to choose the most suitable approach every time

# %% [markdown]
# #### Replacing the Missing Values in the DataFrame

# %% [markdown]
# ##### Store null values in a new variable

# %%
# 59 register as a NaN values would be replaced after predictions
df_hitters_nan = df_hitters_num[df_hitters_num['Salary'].isnull()]
df_hitters_nan
# Out:
#      AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  \
# 0      293    66      1    30   29     14      1     293     66       1
# 15     183    39      3    20   15     11      3     201     42       3
# 18     407   104      6    57   43     65     12    5233   1478     100
# 22      22    10      1     4    2      1      6      84     26       2
# 30     313    84      9    42   30     39     17    6890   1833     224
# 32     517   141     27    70   87     52      9    3571    994     215
# 36     161    36      0    19   10     17      4    1053    244       3
# 38     346    98      5    31   53     30     16    5913   1615     235
# 39     241    61      1    34   12     14      1     241     61       1
# 41     216    54      0    21   18     15     18    7318   1926      46
# 42     200    57      6    23   14     14      9    2516    684      46
# 44     194    40      7    19   29     30     11    4183   1069      64
# 48     542   140     12    46   75     41     16    7099   2130     235
# 52      19     7      0     1    2      1      4      41     13       1
# 57     235    61      3    24   39     21     14    3926   1029      35
# 64      24     3      0     1    0      2      3     159     28       0
# 66     191    37      4    12   17     14      4     773    163      16
# 69     419   113      1    44   27     44     12    4484   1231      32
# 71     138    31      8    18   21     38      3     244     53      12
# 77     195    55      5    24   33     30      8    1313    338      25
# 80     561   118     35    70   94     33     16    6677   1575     442
# 83     227    46      7    23   20     12      5    1325    324      44
# 94     278    69      3    24   21     29      8    2079    565      32
# 97     277    71      2    27   29     14     15    5952   1647      60
# 101    524   132      9    69   47     54      2     972    260      14
# 103    395   106     16    48   56     35     10    2303    571      86
# 104    397   114     23    67   67     53     13    5589   1632     241
# 105    210    37      8    15   19     15      6     994    244      36
# 106    420    95     23    55   58     37      3     646    139      31
# 114    284    64     14    30   42     24     18    7023   1925     348
# 125    315    59     16    45   36     58     13    4677   1051     268
# 138    284    69      1    33   18     25      5    1407    361       6
# 144    209    45      0    38   19     42     10    3859    916      23
# 150    225    61      5    32   26     26     11    1568    408      25
# 157    401   100      2    60   19     28      4     876    238       2
# 158    336    93      9    35   46     23     15    5779   1610     128
# 160    219    47      8    24   26     17     12    1188    286      23
# 169    249    69      6    32   19     20      4     702    209      10
# 171    212    54     13    28   44     18      2     233     59      13
# 173    161    43      4    17   26     22      3     707    179      21
# 197    166    34      0    20   13     17      1     166     34       0
# 199    508   146      8    80   44     46      9    3148    915      41
# 203    243    53      4    18   26     27      4     853    228      23
# 208    209    59      6    20   37     27      4     884    209      14
# 210    317    88      3    40   32     19      8    2543    715      28
# 225    330    76     12    35   41     47      4    1367    326      55
# 228    359    84      4    46   27     21     12    4992   1257      37
# 235    551   160     23    86   90     87      5    2235    602      75
# 246    462   119     16    49   65     37      7    2131    583      69
# 250     33     6      0     2    4      7      1      33      6       0
# 253    186    44      7    28   16     11      1     186     44       7
# 254    307    80      1    42   36     29      7    2421    656      18
# 270    303    84      4    35   32     23      2     312     87       4
# 283     16     2      0     1    0      0      2      28      4       0
# 292    289    63      7    36   41     44     17    7402   1954     195
# 298    181    46      1    19   18     17      5     937    238       9
# 302    200    51      2    14   29     25     23    9778   2732     379
# 305    580   194      9    91   62     78      8    3372   1028      48
# 316    221    53      2    21   23     22      8    1063    283      15
#
#      CRuns  CRBI  CWalks  PutOuts  Assists  Errors  Salary  League_N  \
# 0       30    29      14      446       33      20     NaN     False
# 15      20    16      11      118        0       0     NaN     False
# 18     643   658     653      912       88       9     NaN     False
# 22       9     9       3      812       84      11     NaN     False
# 30    1033   864    1087      127      221       7     NaN     False
# 32     545   652     337     1378      102       8     NaN      True
# 36     156    86     107       70      149      12     NaN     False
# 38     784   901     560        0        0       0     NaN     False
# 39      34    12      14      166      172      10     NaN      True
# 41     796   627     483      103       84       5     NaN      True
# 42     371   230     195       69        1       1     NaN      True
# 44     486   493     608      325       22       2     NaN     False
# 48     987  1089     431      697       61       9     NaN     False
# 52       3     4       4        0        0       0     NaN     False
# 57     441   401     333      425       43       4     NaN     False
# 64      20    12       9       80        4       0     NaN     False
# 66      61    74      52      391       38       8     NaN      True
# 69     612   344     422      211        2       1     NaN     False
# 71      33    32      55      244       21       4     NaN      True
# 77     144   149     153       83        2       1     NaN      True
# 80     901  1210     608      463       32       8     NaN     False
# 83     156   158      67       92        2       2     NaN     False
# 94     258   192     162      142      210      10     NaN      True
# 97     753   596     259      360       32       5     NaN      True
# 101    123    92      90      212      327      20     NaN     False
# 103    266   323     248      709       41       7     NaN     False
# 104    906   926     716      244        2       4     NaN     False
# 105    107   114      53       40      115      15     NaN     False
# 106     77    77      61      206       10       7     NaN      True
# 114    986  1239     666       96        4       4     NaN      True
# 125    681   782     697        0        0       0     NaN     False
# 138    139    98     111      122      140       5     NaN     False
# 144    557   279     478      132      205       5     NaN     False
# 150    202   185     257      132        9       0     NaN     False
# 157    126    44      55      193       11       4     NaN      True
# 158    730   741     497        0        0       0     NaN     False
# 160    100   125      63      260       58       4     NaN     False
# 169     97    48      44      103        8       2     NaN      True
# 171     31    46      20      243       23       5     NaN     False
# 173     77    99      76      300       12       2     NaN     False
# 197     20    13      17       64      119       9     NaN      True
# 199    571   289     326      245        5       9     NaN     False
# 203    101   110      76      107        3       3     NaN      True
# 208     66   106      92      415       35       3     NaN      True
# 210    269   270     118      220       16       4     NaN     False
# 225    167   198     167      512       30       5     NaN      True
# 228    699   386     387      151        8       5     NaN      True
# 235    278   328     273     1224      115      11     NaN     False
# 246    244   288     150      866       65       6     NaN     False
# 250      2     4       7      205        5       4     NaN     False
# 253     28    16      11       99        3       1     NaN      True
# 254    379   198     184      145        2       2     NaN     False
# 270     39    32      23      179        5       3     NaN      True
# 283      1     0       0      247        4       8     NaN     False
# 292   1115   919    1153      166      211       7     NaN     False
# 298     88    95     104       37       98       9     NaN     False
# 302   1272  1652     925      398       29       7     NaN      True
# 305    604   314     469      270       13       6     NaN      True
# 316    107   124     106      325       58       6     NaN      True
#
#      Division_W  NewLeague_N
# 0         False        False
# 15         True        False
# 18         True        False
# 22         True        False
# 30         True        False
# 32         True         True
# 36        False        False
# 38        False        False
# 39         True         True
# 41         True         True
# 42         True         True
# 44        False        False
# 48        False        False
# 52        False        False
# 57        False        False
# 64         True        False
# 66        False         True
# 69        False        False
# 71        False         True
# 77        False         True
# 80         True        False
# 83         True        False
# 94         True         True
# 97         True         True
# 101       False        False
# 103       False        False
# 104       False        False
# 105       False        False
# 106        True         True
# 114       False         True
# 125        True        False
# 138       False         True
# 144        True        False
# 150        True        False
# 157       False         True
# 158        True        False
# 160        True        False
# 169       False         True
# 171       False        False
# 173        True        False
# 197       False         True
# 199        True        False
# 203       False         True
# 208       False         True
# 210        True        False
# 225        True         True
# 228        True         True
# 235        True        False
# 246       False        False
# 250        True        False
# 253        True         True
# 254        True        False
# 270        True         True
# 283       False        False
# 292        True        False
# 298       False        False
# 302        True         True
# 305       False         True
# 316       False         True

# %% [markdown]
# ##### Assign the dependent and independent variables

# %%
X_nan = df_hitters_nan.drop('Salary', axis=1)
y_nan = df_hitters_nan['Salary']

# %%
scaler = StandardScaler()
X_nan = scaler.fit_transform(X_nan)

# %%
nan_pred = ridge.predict(X_nan)
nan_pred
# Out:
# array([ 392.78940486,   81.67108326, 1020.54279961,  328.05241123,
#         731.7032967 , 1294.86708197,  348.80680508,  826.2803275 ,
#         247.04429632,  626.11148259,  313.53020051,  597.22732684,
#        1407.99142344,  151.18500308,  659.33642476,   32.76788545,
#         410.44944613,  716.69211652,  444.57723576,  414.00770086,
#         951.27012871,  164.51679   ,  397.85982369,  756.63559873,
#         662.85289214,  756.35248229, 1077.31652353,  268.53058737,
#         299.27045741, 1003.4839358 ,  519.45310223,  379.62948289,
#         486.68102786,  197.10326024,  449.72180933,  580.29640809,
#         176.44026221,  384.6652987 ,  384.67616694,  275.95941267,
#         326.50223081,  601.57278994,  380.46502713,  543.86356167,
#         392.18773833,  521.61830214,  510.15797952, 1153.97736734,
#         879.25545633,  107.73887905,  148.10030637,  390.5113781 ,
#         251.02876522,  239.78869032,  772.57321847,  301.89309692,
#        1197.74498137, 1020.28080782,  447.86116108])

# %% [markdown]
# #### Populate the dataframe

# %%
df_nan_full = df_hitters_nan.copy()
df_nan_full['Salary'] = nan_pred
df_nan_full
# Out:
#      AtBat  Hits  HmRun  Runs  RBI  Walks  Years  CAtBat  CHits  CHmRun  \
# 0      293    66      1    30   29     14      1     293     66       1
# 15     183    39      3    20   15     11      3     201     42       3
# 18     407   104      6    57   43     65     12    5233   1478     100
# 22      22    10      1     4    2      1      6      84     26       2
# 30     313    84      9    42   30     39     17    6890   1833     224
# 32     517   141     27    70   87     52      9    3571    994     215
# 36     161    36      0    19   10     17      4    1053    244       3
# 38     346    98      5    31   53     30     16    5913   1615     235
# 39     241    61      1    34   12     14      1     241     61       1
# 41     216    54      0    21   18     15     18    7318   1926      46
# 42     200    57      6    23   14     14      9    2516    684      46
# 44     194    40      7    19   29     30     11    4183   1069      64
# 48     542   140     12    46   75     41     16    7099   2130     235
# 52      19     7      0     1    2      1      4      41     13       1
# 57     235    61      3    24   39     21     14    3926   1029      35
# 64      24     3      0     1    0      2      3     159     28       0
# 66     191    37      4    12   17     14      4     773    163      16
# 69     419   113      1    44   27     44     12    4484   1231      32
# 71     138    31      8    18   21     38      3     244     53      12
# 77     195    55      5    24   33     30      8    1313    338      25
# 80     561   118     35    70   94     33     16    6677   1575     442
# 83     227    46      7    23   20     12      5    1325    324      44
# 94     278    69      3    24   21     29      8    2079    565      32
# 97     277    71      2    27   29     14     15    5952   1647      60
# 101    524   132      9    69   47     54      2     972    260      14
# 103    395   106     16    48   56     35     10    2303    571      86
# 104    397   114     23    67   67     53     13    5589   1632     241
# 105    210    37      8    15   19     15      6     994    244      36
# 106    420    95     23    55   58     37      3     646    139      31
# 114    284    64     14    30   42     24     18    7023   1925     348
# 125    315    59     16    45   36     58     13    4677   1051     268
# 138    284    69      1    33   18     25      5    1407    361       6
# 144    209    45      0    38   19     42     10    3859    916      23
# 150    225    61      5    32   26     26     11    1568    408      25
# 157    401   100      2    60   19     28      4     876    238       2
# 158    336    93      9    35   46     23     15    5779   1610     128
# 160    219    47      8    24   26     17     12    1188    286      23
# 169    249    69      6    32   19     20      4     702    209      10
# 171    212    54     13    28   44     18      2     233     59      13
# 173    161    43      4    17   26     22      3     707    179      21
# 197    166    34      0    20   13     17      1     166     34       0
# 199    508   146      8    80   44     46      9    3148    915      41
# 203    243    53      4    18   26     27      4     853    228      23
# 208    209    59      6    20   37     27      4     884    209      14
# 210    317    88      3    40   32     19      8    2543    715      28
# 225    330    76     12    35   41     47      4    1367    326      55
# 228    359    84      4    46   27     21     12    4992   1257      37
# 235    551   160     23    86   90     87      5    2235    602      75
# 246    462   119     16    49   65     37      7    2131    583      69
# 250     33     6      0     2    4      7      1      33      6       0
# 253    186    44      7    28   16     11      1     186     44       7
# 254    307    80      1    42   36     29      7    2421    656      18
# 270    303    84      4    35   32     23      2     312     87       4
# 283     16     2      0     1    0      0      2      28      4       0
# 292    289    63      7    36   41     44     17    7402   1954     195
# 298    181    46      1    19   18     17      5     937    238       9
# 302    200    51      2    14   29     25     23    9778   2732     379
# 305    580   194      9    91   62     78      8    3372   1028      48
# 316    221    53      2    21   23     22      8    1063    283      15
#
#      CRuns  CRBI  CWalks  PutOuts  Assists  Errors       Salary  League_N  \
# 0       30    29      14      446       33      20   392.789405     False
# 15      20    16      11      118        0       0    81.671083     False
# 18     643   658     653      912       88       9  1020.542800     False
# 22       9     9       3      812       84      11   328.052411     False
# 30    1033   864    1087      127      221       7   731.703297     False
# 32     545   652     337     1378      102       8  1294.867082      True
# 36     156    86     107       70      149      12   348.806805     False
# 38     784   901     560        0        0       0   826.280328     False
# 39      34    12      14      166      172      10   247.044296      True
# 41     796   627     483      103       84       5   626.111483      True
# 42     371   230     195       69        1       1   313.530201      True
# 44     486   493     608      325       22       2   597.227327     False
# 48     987  1089     431      697       61       9  1407.991423     False
# 52       3     4       4        0        0       0   151.185003     False
# 57     441   401     333      425       43       4   659.336425     False
# 64      20    12       9       80        4       0    32.767885     False
# 66      61    74      52      391       38       8   410.449446      True
# 69     612   344     422      211        2       1   716.692117     False
# 71      33    32      55      244       21       4   444.577236      True
# 77     144   149     153       83        2       1   414.007701      True
# 80     901  1210     608      463       32       8   951.270129     False
# 83     156   158      67       92        2       2   164.516790     False
# 94     258   192     162      142      210      10   397.859824      True
# 97     753   596     259      360       32       5   756.635599      True
# 101    123    92      90      212      327      20   662.852892     False
# 103    266   323     248      709       41       7   756.352482     False
# 104    906   926     716      244        2       4  1077.316524     False
# 105    107   114      53       40      115      15   268.530587     False
# 106     77    77      61      206       10       7   299.270457      True
# 114    986  1239     666       96        4       4  1003.483936      True
# 125    681   782     697        0        0       0   519.453102     False
# 138    139    98     111      122      140       5   379.629483     False
# 144    557   279     478      132      205       5   486.681028     False
# 150    202   185     257      132        9       0   197.103260     False
# 157    126    44      55      193       11       4   449.721809      True
# 158    730   741     497        0        0       0   580.296408     False
# 160    100   125      63      260       58       4   176.440262     False
# 169     97    48      44      103        8       2   384.665299      True
# 171     31    46      20      243       23       5   384.676167     False
# 173     77    99      76      300       12       2   275.959413     False
# 197     20    13      17       64      119       9   326.502231      True
# 199    571   289     326      245        5       9   601.572790     False
# 203    101   110      76      107        3       3   380.465027      True
# 208     66   106      92      415       35       3   543.863562      True
# 210    269   270     118      220       16       4   392.187738     False
# 225    167   198     167      512       30       5   521.618302      True
# 228    699   386     387      151        8       5   510.157980      True
# 235    278   328     273     1224      115      11  1153.977367     False
# 246    244   288     150      866       65       6   879.255456     False
# 250      2     4       7      205        5       4   107.738879     False
# 253     28    16      11       99        3       1   148.100306      True
# 254    379   198     184      145        2       2   390.511378     False
# 270     39    32      23      179        5       3   251.028765      True
# 283      1     0       0      247        4       8   239.788690     False
# 292   1115   919    1153      166      211       7   772.573218     False
# 298     88    95     104       37       98       9   301.893097     False
# 302   1272  1652     925      398       29       7  1197.744981      True
# 305    604   314     469      270       13       6  1020.280808      True
# 316    107   124     106      325       58       6   447.861161      True
#
#      Division_W  NewLeague_N
# 0         False        False
# 15         True        False
# 18         True        False
# 22         True        False
# 30         True        False
# 32         True         True
# 36        False        False
# 38        False        False
# 39         True         True
# 41         True         True
# 42         True         True
# 44        False        False
# 48        False        False
# 52        False        False
# 57        False        False
# 64         True        False
# 66        False         True
# 69        False        False
# 71        False         True
# 77        False         True
# 80         True        False
# 83         True        False
# 94         True         True
# 97         True         True
# 101       False        False
# 103       False        False
# 104       False        False
# 105       False        False
# 106        True         True
# 114       False         True
# 125        True        False
# 138       False         True
# 144        True        False
# 150        True        False
# 157       False         True
# 158        True        False
# 160        True        False
# 169       False         True
# 171       False        False
# 173        True        False
# 197       False         True
# 199        True        False
# 203       False         True
# 208       False         True
# 210        True        False
# 225        True         True
# 228        True         True
# 235        True        False
# 246       False        False
# 250        True        False
# 253        True         True
# 254        True        False
# 270        True         True
# 283       False        False
# 292        True        False
# 298       False        False
# 302        True         True
# 305       False         True
# 316       False         True
