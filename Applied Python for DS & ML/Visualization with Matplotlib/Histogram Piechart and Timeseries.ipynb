# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv("E:\DATA SETS\earthquakedb.csv")
df.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
df.shape
# Out:
# (23412, 21)

# %%
df.info() #date is an object and Time same
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23412 entries, 0 to 23411
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        23412 non-null  object
#  1   Time                        23412 non-null  object
#  2   Latitude                    23412 non-null  float64
#  3   Longitude                   23412 non-null  float64
#  4   Type                        23412 non-null  object
#  5   Depth                       23412 non-null  float64
#  6   Depth Error                 4461 non-null   float64
#  7   Depth Seismic Stations      7097 non-null   float64
#  8   Magnitude                   23412 non-null  float64
#  9   Magnitude Type              23409 non-null  object
#  10  Magnitude Error             327 non-null    float64
#  11  Magnitude Seismic Stations  2564 non-null   float64
#  12  Azimuthal Gap               7299 non-null   float64
# ...

# %% [markdown]
# #### Histogram

# %%
fig, ax = plt.subplots()

# %%
fig, ax = plt.subplots()
ax.hist(df["Magnitude"])
# Out:
# (array([1.4107e+04, 5.6570e+03, 1.8100e+03, 1.1000e+03, 3.9300e+02,
#         2.1400e+02, 1.0400e+02, 1.9000e+01, 5.0000e+00, 3.0000e+00]),
#  array([5.5 , 5.86, 6.22, 6.58, 6.94, 7.3 , 7.66, 8.02, 8.38, 8.74, 9.1 ]),
#  <BarContainer object of 10 artists>)

# %%
fig, ax = plt.subplots()
ax.hist(df["Magnitude"], bins=50)
# Out:
# (array([4.693e+03, 3.972e+03, 3.084e+03, 6.000e+00, 2.352e+03, 1.949e+03,
#         1.582e+03, 1.000e+00, 1.213e+03, 9.120e+02, 0.000e+00, 7.680e+02,
#         5.740e+02, 4.670e+02, 1.000e+00, 3.630e+02, 3.140e+02, 0.000e+00,
#         2.360e+02, 1.870e+02, 1.680e+02, 0.000e+00, 1.230e+02, 1.020e+02,
#         0.000e+00, 6.300e+01, 5.900e+01, 4.300e+01, 0.000e+00, 4.900e+01,
#         3.900e+01, 3.100e+01, 0.000e+00, 2.100e+01, 1.300e+01, 0.000e+00,
#         7.000e+00, 7.000e+00, 5.000e+00, 0.000e+00, 2.000e+00, 0.000e+00,
#         0.000e+00, 2.000e+00, 1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 2.000e+00]),
#  array([5.5  , 5.572, 5.644, 5.716, 5.788, 5.86 , 5.932, 6.004, 6.076,
#         6.148, 6.22 , 6.292, 6.364, 6.436, 6.508, 6.58 , 6.652, 6.724,
#         6.796, 6.868, 6.94 , 7.012, 7.084, 7.156, 7.228, 7.3  , 7.372,
#         7.444, 7.516, 7.588, 7.66 , 7.732, 7.804, 7.876, 7.948, 8.02 ,
# ...

# %%
fig, ax = plt.subplots()
ax.hist(df["Magnitude"], bins=40)
# Out:
# (array([4.694e+03, 3.975e+03, 3.084e+03, 2.354e+03, 1.950e+03, 1.582e+03,
#         1.213e+03, 9.120e+02, 7.650e+02, 3.000e+00, 5.770e+02, 4.650e+02,
#         3.630e+02, 3.140e+02, 2.360e+02, 1.870e+02, 1.680e+02, 1.230e+02,
#         1.020e+02, 0.000e+00, 6.300e+01, 5.900e+01, 4.300e+01, 4.900e+01,
#         3.900e+01, 3.100e+01, 2.100e+01, 1.300e+01, 7.000e+00, 0.000e+00,
#         7.000e+00, 5.000e+00, 2.000e+00, 0.000e+00, 2.000e+00, 1.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 2.000e+00]),
#  array([5.5 , 5.59, 5.68, 5.77, 5.86, 5.95, 6.04, 6.13, 6.22, 6.31, 6.4 ,
#         6.49, 6.58, 6.67, 6.76, 6.85, 6.94, 7.03, 7.12, 7.21, 7.3 , 7.39,
#         7.48, 7.57, 7.66, 7.75, 7.84, 7.93, 8.02, 8.11, 8.2 , 8.29, 8.38,
#         8.47, 8.56, 8.65, 8.74, 8.83, 8.92, 9.01, 9.1 ]),
#  <BarContainer object of 40 artists>)

# %%
fig, ax = plt.subplots()
ax.hist(df["Magnitude"], bins=40, range=[5.5,8.0])
# Out:
# (array([4.693e+03, 3.969e+03, 7.000e+00, 3.082e+03, 2.351e+03, 5.000e+00,
#         1.949e+03, 2.000e+00, 1.581e+03, 1.213e+03, 0.000e+00, 9.120e+02,
#         7.660e+02, 2.000e+00, 5.740e+02, 3.000e+00, 4.640e+02, 3.640e+02,
#         0.000e+00, 3.140e+02, 2.360e+02, 0.000e+00, 1.870e+02, 0.000e+00,
#         1.680e+02, 1.230e+02, 0.000e+00, 1.020e+02, 6.300e+01, 0.000e+00,
#         5.900e+01, 0.000e+00, 4.300e+01, 4.900e+01, 0.000e+00, 3.900e+01,
#         3.100e+01, 0.000e+00, 2.100e+01, 1.300e+01]),
#  array([5.5   , 5.5625, 5.625 , 5.6875, 5.75  , 5.8125, 5.875 , 5.9375,
#         6.    , 6.0625, 6.125 , 6.1875, 6.25  , 6.3125, 6.375 , 6.4375,
#         6.5   , 6.5625, 6.625 , 6.6875, 6.75  , 6.8125, 6.875 , 6.9375,
#         7.    , 7.0625, 7.125 , 7.1875, 7.25  , 7.3125, 7.375 , 7.4375,
#         7.5   , 7.5625, 7.625 , 7.6875, 7.75  , 7.8125, 7.875 , 7.9375,
#         8.    ]),
#  <BarContainer object of 40 artists>)

# %%
fig, ax = plt.subplots()
ax.hist(df["Magnitude"], bins=40,color='red')
# Out:
# (array([4.694e+03, 3.975e+03, 3.084e+03, 2.354e+03, 1.950e+03, 1.582e+03,
#         1.213e+03, 9.120e+02, 7.650e+02, 3.000e+00, 5.770e+02, 4.650e+02,
#         3.630e+02, 3.140e+02, 2.360e+02, 1.870e+02, 1.680e+02, 1.230e+02,
#         1.020e+02, 0.000e+00, 6.300e+01, 5.900e+01, 4.300e+01, 4.900e+01,
#         3.900e+01, 3.100e+01, 2.100e+01, 1.300e+01, 7.000e+00, 0.000e+00,
#         7.000e+00, 5.000e+00, 2.000e+00, 0.000e+00, 2.000e+00, 1.000e+00,
#         1.000e+00, 0.000e+00, 0.000e+00, 2.000e+00]),
#  array([5.5 , 5.59, 5.68, 5.77, 5.86, 5.95, 6.04, 6.13, 6.22, 6.31, 6.4 ,
#         6.49, 6.58, 6.67, 6.76, 6.85, 6.94, 7.03, 7.12, 7.21, 7.3 , 7.39,
#         7.48, 7.57, 7.66, 7.75, 7.84, 7.93, 8.02, 8.11, 8.2 , 8.29, 8.38,
#         8.47, 8.56, 8.65, 8.74, 8.83, 8.92, 9.01, 9.1 ]),
#  <BarContainer object of 40 artists>)

# %% [markdown]
# #### Piechart

# %%
print(df['Date'].dtype)
# Out:
# object

# %%
print(df['Time'].dtype)
# Out:
# object

# %%
# change format of date and time columns
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S', errors='coerce')

# %%
df['Date']
# Out:
# 0        01/02/1965
# 1        01/04/1965
# 2        01/05/1965
# 3        01/08/1965
# 4        01/09/1965
#             ...
# 23407    12/28/2016
# 23408    12/28/2016
# 23409    12/28/2016
# 23410    12/29/2016
# 23411    12/30/2016
# Name: Date, Length: 23412, dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y', errors='coerce')

# %%
df['weekday'] = pd.to_datetime(df['Date'],utc=True).dt.day_name()

# %%
#Date and Time with datetime format
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23412 entries, 0 to 23411
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        23409 non-null  datetime64[ns]
#  1   Time                        23409 non-null  datetime64[ns]
#  2   Latitude                    23412 non-null  float64
#  3   Longitude                   23412 non-null  float64
#  4   Type                        23412 non-null  object
#  5   Depth                       23412 non-null  float64
#  6   Depth Error                 4461 non-null   float64
#  7   Depth Seismic Stations      7097 non-null   float64
#  8   Magnitude                   23412 non-null  float64
#  9   Magnitude Type              23409 non-null  object
#  10  Magnitude Error             327 non-null    float64
#  11  Magnitude Seismic Stations  2564 non-null   float64
# ...

# %%
grp = df.groupby("weekday")
grp.count()
# Out:
#            Date  Time  Latitude  Longitude  Type  Depth  Depth Error  \
# weekday
# Friday     3362  3362      3362       3362  3362   3362          710
# Monday     3349  3349      3349       3349  3349   3349          656
# Saturday   3433  3433      3433       3433  3433   3433          649
# Sunday     3284  3284      3284       3284  3284   3284          601
# Thursday   3306  3306      3306       3306  3306   3306          612
# Tuesday    3244  3244      3244       3244  3244   3244          595
# Wednesday  3431  3431      3431       3431  3431   3431          637
#
#            Depth Seismic Stations  Magnitude  Magnitude Type  ...  \
# weekday                                                       ...
# Friday                       1054       3362            3361  ...
# Monday                        960       3349            3348  ...
# Saturday                     1039       3433            3433  ...
# Sunday                       1025       3284            3284  ...
# ...

# %%
grp = df.groupby("weekday")
grp["weekday"].count()
# Out:
# weekday
# Friday       3362
# Monday       3349
# Saturday     3433
# Sunday       3284
# Thursday     3306
# Tuesday      3244
# Wednesday    3431
# Name: weekday, dtype: int64

# %%
grp = df.groupby("weekday")
series = grp["weekday"].count()
names = series.keys()
numbers = series.values

# %%
fig, ax = plt.subplots()
ax.pie(numbers)
# Out:
# ([<matplotlib.patches.Wedge at 0x2aecd7f0f40>,
# ...
#  [Text(0.9899191317584148, 0.47964581993244393, ''),
#   Text(0.2389302788367924, 1.0737375479394269, ''),
#   Text(-0.7012255031115594, 0.8475156599060223, ''),
#   Text(-1.0997368200864805, -0.02406089246216962, ''),
#   Text(-0.6783438652237599, -0.8659385662466418, ''),
#   Text(0.23417255384149785, -1.0747851948307396, ''),
#   Text(0.9854351352933903, -0.4887919742889582, '')])

# %%
fig, ax = plt.subplots()
ax.pie(numbers, labels=names)
plt.show() #tis show just the plot

# %%
fig, ax = plt.subplots()
ax.pie(numbers, labels=names, autopct='%.1f') #1 decimales places
plt.show() #tis show just the plot

# %%
fig, ax = plt.subplots()
ax.pie(numbers, labels=names, autopct='%.1f%%') #1 decimales places
plt.show() #tis show just the plot

# %% [markdown]
# #### Time Series

# %%
print(df['Time'].dtype)
# Out:
# datetime64[ns]

# %%
#create the year column
df['year'] = df['Date'].dt.year

# %%
df['year']
# Out:
# 0        1965.0
# 1        1965.0
# 2        1965.0
# 3        1965.0
# 4        1965.0
#           ...
# 23407    2016.0
# 23408    2016.0
# 23409    2016.0
# 23410    2016.0
# 23411    2016.0
# Name: year, Length: 23412, dtype: float64

# %%
#series2
grp2 = df.groupby("year")
series2 = grp2["year"].count()
x = series2.keys()
y = series2.values
series2
# Out:
# year
# 1965.0    339
# 1966.0    234
# 1967.0    255
# 1968.0    305
# 1969.0    323
# 1970.0    345
# 1971.0    386
# 1972.0    388
# 1973.0    401
# 1974.0    361
# 1975.0    411
# 1976.0    457
# 1977.0    425
# 1978.0    410
# 1979.0    356
# 1980.0    348
# 1981.0    321
# 1982.0    346
# 1983.0    453
# 1984.0    482
# 1985.0    475
# 1986.0    485
# 1987.0    505
# 1988.0    489
# 1989.0    480
# 1990.0    528
# 1991.0    429
# 1992.0    533
# 1993.0    466
# 1994.0    508
# 1995.0    591
# 1996.0    541
# 1997.0    456
# 1998.0    388
# 1999.0    446
# 2000.0    553
# 2001.0    443
# 2002.0    444
# 2003.0    485
# 2004.0    571
# 2005.0    533
# 2006.0    508
# 2007.0    608
# 2008.0    508
# 2009.0    517
# 2010.0    560
# 2011.0    712
# 2012.0    445
# 2013.0    461
# 2014.0    480
# 2015.0    446
# 2016.0    469
# Name: year, dtype: int64

# %%
length = len(df['year'])
print(length)
# Out:
# 23412

# %%
num_rows = df.shape[0]
print(num_rows)
# Out:
# 23412

# %%
fig, ax = plt.subplots()

# %%
fig, ax = plt.subplots()
ax.plot(x,y)
