# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_excel("E:\PYTHON BILDUNG\Python Mini E_Degre\Applied Python for DS & ML\Data Analysis with Pandas\export4.xlsx")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1             51            35             14             2        1
# 1   2             49            30             14             2        1
# 2   3             47            32             13             2        1
# 3   4             46            31             15             2        1
# 4   5             50            36             14             2        1

# %%
df["Species"].unique()
# Out:
# array([1, 2, 3], dtype=int64)

# %%
fig, ax = plt.subplots()
ax.scatter(df["SepalLengthCm"], df["PetalLengthCm"])

# %%
fig, ax = plt.subplots()
ax.scatter(df["SepalLengthCm"], df["PetalLengthCm"], c=df["Species"])

# %%
fig, ax = plt.subplots()
x = df["SepalLengthCm"]
y = df["PetalLengthCm"]
ax.scatter(x, y, c=df["Species"])
